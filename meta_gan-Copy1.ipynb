# %%
import  torch
from    torch import nn
from    torch import optim
from    torch.nn import functional as F
from    torch.utils.data import TensorDataset, DataLoader
from    torch import optim
import  numpy as np
from torch.autograd import Variable

from   models.learner import Learner
from models.generator import Generator
from    copy import deepcopy
import os
from torchsummary import summary

from utils.dataloader import train_data_gen , test_data_gen
import shutil
import matplotlib.pyplot as plt
import tqdm.notebook as tqdm
from torch.utils.tensorboard import SummaryWriter
import json
# import tqdm

# %%
with open('configs/0619_5way1shot.json') as json_file:
    args = json.load(json_file)

# %%
print(args)
# Out:
# {'epoch': 96000, 'n_way': 5, 'k_spt': 1, 'k_qry': 15, 'img_sz': 84, 'tasks_per_batch': 5, 'img_c': 3, 'meta_gen_lr': 0.0005, 'meta_discrim_lr': 0.0001, 'update_lr': 0.004, 'update_steps': 2, 'update_steps_test': 2, 'loss': 'cross_entropy', 'min_learning_rate': 1e-15, 'number_of_training_steps_per_iter': 4, 'multi_step_loss_num_epochs': 15, 'spy_gen_num': 5, 'qry_gen_num': 25, 'num_distractor': 0, 'batch_for_gradient': 25, 'no_save': 0, 'learn_inner_lr': 0, 'create_graph': 0, 'msl': 0, 'single_fast_test': 0, 'consine_schedule': 0, 'save_path': '0619_5way1shot'}

# %%
# if os.path.exists("images/" + args["save_path"]):
#     shutil.rmtree("images/" + args["save_path"])
    
# if os.path.exists("data/" + args["save_path"]):
#     shutil.rmtree("data/" + args["save_path"])
    
# if os.path.exists("save_models/" + args["save_path"]):
#     shutil.rmtree("save_models/" + args["save_path"])
    
# if os.path.exists("runs/" + args["save_path"]):
#     shutil.rmtree("runs/" + args["save_path"])    

writer = SummaryWriter('runs/' + args["save_path"])

# %%
def mkdir_p(path):
    if not os.path.exists("images/" + path):
        os.makedirs("images/" + path)
        
    if not os.path.exists("data/" + path):
        os.makedirs("data/" + path)
        
    if not os.path.exists("save_models/" + path):
        os.makedirs("save_models/" + path)        

def save_imgs(path, imgs, step):

    some_imgs = np.reshape(imgs, [imgs.shape[0]*imgs.shape[1], -1])[0:50]

    # save png of imgs
    i = 0
    for flat_img in some_imgs:
        img = flat_img.reshape(3,84,84).swapaxes(0,1).swapaxes(1,2)
        im = ((img - np.min(img))*255/(np.max(img - np.min(img)))).astype(np.uint8)
        if i < 15:
            plt.subplot(5, 3, i+1)
            plt.axis('off')
            plt.imshow(im)
        i += 1
    plt.savefig("images/" + path + "/images_step" + str(step) + ".png")
    plt.close()

# %%
train_data_generator = train_data_gen(args)
test_data_generator = test_data_gen(args)
# Out:
# load datasets/BelgiumTSC
# load complete time 0.3165709972381592
# load datasets/ArTS
# load complete time 0.344893217086792
# load datasets/chinese_traffic_sign
# load complete time 0.5611824989318848
# load datasets/CVL
# load complete time 0.3921802043914795
# load datasets/FullJCNN2013
# load complete time 0.21635031700134277
# load datasets/logo_2k
# load complete time 0.9406096935272217
# load datasets/GTSRB
# load complete time 0.08215689659118652
# load datasets/DFG
# load complete time 0.03256702423095703

# %%
ndf = 64
discriminator_config = [
    ('conv2d', [ndf, 3, 4, 4, 2, 1]),
    ('leakyrelu', [0.2,True]),
    # ('bn', [ndf]),
    
    ('conv2d', [ndf*2, ndf, 4, 4, 2, 1]),
    ('bn', [ndf*2]),
    ('leakyrelu', [0.2,True]),

    ('conv2d', [ndf*4, ndf*2, 4, 4, 2, 1]),
    ('bn', [ndf*4]),
    ('leakyrelu', [0.2,True]),
    
    
    ('conv2d', [ndf*8, ndf*4, 4, 4, 2, 1]),
    ('bn', [ndf*8]),
    ('leakyrelu', [0.2,True]),
    
    ('conv2d', [1,ndf*8 , 2, 2, 1, 0]),
    ('flatten', []),
    ('linear',[6, 16]),
    ('softmax',[])
]
nz = 100
ngf = 64
gen_config = [
    ('convert_z',[]),
    ('convt2d',[nz,ngf*8,4,4,1,0]),
    ('bn',[ngf * 8]),
    ('leakyrelu', [.2, True]),  
    
    ('convt2d',[ngf*8,ngf*4,4,4,2,0]),
    ('bn',[ngf * 4]),
    ('leakyrelu', [.2, True]),  
    
    ('convt2d',[ngf*4,ngf*2,4,4,2,0]),
    ('bn',[ngf * 2]),
    ('leakyrelu', [.2, True]),  
    
    ('convt2d',[ngf*2,ngf,3,3,2,1]),
    ('bn',[ngf]),
    ('leakyrelu', [.2, True]),      
    
    ('convt2d',[ngf,3,3,3,2,1]),
    ('convt2d',[3,3,2,2,1,1]),
    ("tanh",[])
]

# %%
class Meta(nn.Module):
    """
    Meta Learner with GAN incorporated
    """
    def __init__(self, args, discriminator_config, gen_config):
        """
        :param args:
        """
        super(Meta, self).__init__()
        
        cuda = torch.cuda.is_available()
        self.FloatTensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor 
        self.LongTensor = torch.cuda.LongTensor if cuda else torch.LongTensor
        self.total_epochs = args["epoch"]   
        # model parameters config
        self.meta_gen_lr = args["meta_gen_lr"]
        self.meta_discrim_lr = args["meta_discrim_lr"]
        
        self.update_lr = args["update_lr"]
        self.consine_schedule = args["consine_schedule"]
        self.update_steps = args["update_steps"]
        self.update_steps_test = args["update_steps_test"]

        # dataset config
        self.img_c = args["img_c"]
        self.img_sz = args["img_sz"]        
        self.n_way = args["n_way"]
        self.k_spt = args["k_spt"]
        self.k_qry = args["k_qry"]
        self.MSL = args["msl"]
        # generator num
        self.spy_gen_num = args["spy_gen_num"]
        self.qry_gen_num = args["qry_gen_num"]
        # query gan batch
        self.batch_for_gradient = args["batch_for_gradient"]
        self.fix_noise = torch.randn(self.qry_gen_num, nz,1,1, device=device)
        self.criterion = nn.BCELoss()
        # load model
        self.generator = Generator(gen_config, self.img_c, self.img_sz)
        self.discrim_net = Learner(discriminator_config, self.img_c, self.img_sz)
        beta1 = 0.0
        beta2 = 0.0
        
        self.meta_gen_optim = optim.Adam(self.generator.parameters(), lr=self.meta_gen_lr,betas=(beta1, 0.9))
        self.meta_d_optim = optim.Adam(self.discrim_net.parameters(), lr=self.meta_discrim_lr,betas=(beta2, 0.9))
        if self.consine_schedule:
            self.min_learning_rate = 1e-8
            self.scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer=self.meta_d_optim, T_max=self.total_epochs,
                                                                  eta_min=self.min_learning_rate)
        self.real_value = 1
        self.fake_value = 0
        self.discrim_fake = 5
    def cross_entropy(self, output,label):
        output = torch.log(output)
        loss = F.nll_loss(output,label)
        return loss
    
    def pred(self, x, weights=None, nets=None, nway=True, discrim=True, conditions=False):
        if weights == None:
            discrim_weights = self.discrim_net.parameters()
        else:
            discrim_weights = weights

        discrim_logits = self.discrim_net(x, vars=discrim_weights, bn_training=True) if discrim else None
          
        return discrim_logits

    def get_num_corrects(self, y, x=None, weights=None, real=True):
        with torch.no_grad():
            discrim_logits = self.pred(x, weights=weights)
            if real :
                nway_pred_q = discrim_logits[:,:-1].argmax(dim=1)
            else:
                nway_pred_q = discrim_logits.argmax(dim=1)
            
            nway_correct = torch.eq(nway_pred_q, y).sum().item()
            pred_q = discrim_logits.argmax(dim=1)
            other = torch.tensor([5]*len(discrim_logits)).cuda()
            other_correct = torch.eq(pred_q, other).sum().item()
        return nway_correct, other_correct

        
    def update_weights(self, net_losses, net_weights,learned_lrs, gen=False):
        if gen:
            update_lr = self.gen_update_lr
        else:
            update_lr = self.update_lr
        # grad = torch.autograd.grad(net_losses, net_weights, retain_graph=True, create_graph=self.create_graph)
        grad = torch.autograd.grad(net_losses, net_weights)
        weights = list(map(lambda p: p[1] - update_lr * p[0], zip(grad, net_weights)))

        return weights
    
    def meta_test(self,qry_img,qry_label,discrim_weight,gen_weight):
        ### discriminator train
        q_real_discrim_logits = self.pred(qry_img, weights=discrim_weight)

        real_discrim_loss_q = self.cross_entropy(q_real_discrim_logits, qry_label)
        if torch.isnan(real_discrim_loss_q):
            print(self.current_epoch)
            print("real d loss error")
            print(q_real_discrim_logits)
            
        discrim_fake_label = torch.full((self.qry_gen_num,), self.discrim_fake, dtype=torch.long, device=device) 
        noise = torch.randn(self.qry_gen_num, nz,1,1, device=device)
        q_gen = torch.empty(0,3,84,84).cuda()
        if self.qry_gen_num < self.batch_for_gradient:

            q_gen = self.generator(qry_img, noise , vars=gen_weight)
        else:
            for i in range(self.qry_gen_num//self.batch_for_gradient):

                noise_tmp = noise[i*self.batch_for_gradient:(i+1)*self.batch_for_gradient]

                q_gen = torch.cat([q_gen,self.generator(qry_img[i*self.batch_for_gradient:(i+1)*self.batch_for_gradient], noise_tmp , vars=gen_weight)])
        q_fake_discrim_logits = self.pred(q_gen.detach(), weights=discrim_weight)
        fake_discrim_loss_q = self.cross_entropy(q_fake_discrim_logits, discrim_fake_label)

        if torch.isnan(fake_discrim_loss_q):
            print("fake d loss error")
            print(q_fake_discrim_logits)
        d_loss_q = (fake_discrim_loss_q + real_discrim_loss_q)
        
        ### generator train
        gen_fake_label = torch.full((self.qry_gen_num,), self.real_value, dtype=torch.float, device=device)
        gen_q_discrim = 1 - self.pred(q_gen, weights=discrim_weight)[:,-1]

        g_loss_q = self.criterion(gen_q_discrim, gen_fake_label)
        if torch.isnan(g_loss_q):
            print("g loss error")
            
        return d_loss_q, g_loss_q

    def single_task_forward(self, x_spt, y_spt, x_qry, y_qry, update_steps,nets=None, images=False):
        
        corrects = {key: np.zeros(update_steps + 1) for key in 
                        [
                        "query_nway", # number of meta-test (query) images correctly discriminated
                        "predict_other",
                        "gen_discrim", # number of generated images correctly discriminated
                        ]}

        support_sz, c_, h, w = x_spt.size()
        nz = 100
        
        discrim_weights,gen_weights = [x.parameters() for x in nets]

        # this is the meta-test loss and accuracy before first update

        q_discrim,other = self.get_num_corrects(y=y_qry, weights=None, x=x_qry)
        corrects["query_nway"][0] += q_discrim
        corrects["predict_other"][0] += other
        # run the i-th task and compute loss for k-th inner update
        query_fake_label = torch.full((self.qry_gen_num,), self.discrim_fake, dtype=torch.long, device=device)
        for k in range(1, update_steps + 1):
            ## discrim loss
            noise = torch.randn(self.spy_gen_num, nz , 1, 1, device=device)
            x_gen = self.generator(x_spt, noise , vars=gen_weights)
            
            # update discrim weight

            real_discrim_logits = self.pred(x_spt, weights=discrim_weights)
            if (True in torch.isnan(real_discrim_logits)):
                print("inner real d loss error")
                print(real_discrim_logits)
            fake_discrim_logits = self.pred(x_gen, weights=discrim_weights)
            if (True in torch.isnan(fake_discrim_logits)):
                print("inner fake d loss error")
                print(fake_discrim_logits)
            fake_label = torch.full((self.spy_gen_num,), self.discrim_fake, dtype=torch.long, device=device)
            
            real_discrim_loss = self.cross_entropy(real_discrim_logits, y_spt)
            fake_discrim_loss = self.cross_entropy(fake_discrim_logits,fake_label)
            D_loss = fake_discrim_loss + real_discrim_loss

            discrim_weights = self.update_weights(D_loss, discrim_weights,self.update_lr) 
            
            with torch.no_grad():
                x_gen = self.generator(x_qry, self.fix_noise , vars=gen_weights) 
                gen_correct,_ = self.get_num_corrects(y=query_fake_label,x=x_gen, weights=discrim_weights,real=False)
                corrects["gen_discrim"][k-1] += gen_correct
                
                q_discrim_correct,other = self.get_num_corrects(y=y_qry, x=x_qry, weights=discrim_weights)
                corrects['query_nway'][k] += q_discrim_correct
                corrects["predict_other"][k] += other
            # meta-test nway and discrim accuracy
            # [query_sz]

        # final gen-discrim and gen-nway accuracy
        with torch.no_grad():
            x_gen = self.generator(x_qry, self.fix_noise , vars=gen_weights)
            gen_correct,_ = self.get_num_corrects(y=query_fake_label,x=x_gen, weights=discrim_weights,real=False)
            corrects["gen_discrim"][-1] += gen_correct
        d_loss_q, g_loss_q = self.meta_test(x_qry,y_qry,discrim_weights,gen_weights)
            
        if images:
            return d_loss_q,g_loss_q, corrects, x_gen
        else:
            return d_loss_q,g_loss_q, corrects

    def forward(self, x_spt, y_spt, x_qry, y_qry,step):
        """
        :param x_spt:   [b, support_sz, c_, h, w]
        :param y_spt:   [b, support_sz]
        :param x_qry:   [b, query_sz, c_, h, w]
        :param y_qry:   [b, query_sz]
        :return:
        """
        self.current_epoch = step 
        tasks_per_batch, support_sz, c_, h, w = x_spt.size()
        query_sz = x_qry.size(1)
        g_loss_q = 0
        d_loss_q = 0
        gen_losses_q = [0 for _ in range(self.update_steps + 1)]
        discrim_losses_q = [0 for _ in range(self.update_steps + 1)]
        corrects = {key: np.zeros(self.update_steps + 1) for key in 
                        [
                        "query_nway", # number of meta-test (query) images correctly discriminated
                        "predict_other",
                        "gen_discrim", # number of generated images correctly discriminated
                        ]}
        net = [self.discrim_net,self.generator]
        for i in range(tasks_per_batch):
            d_loss_q_tmp,g_loss_q_tmp, corrects_tmp = self.single_task_forward(x_spt[i], y_spt[i], x_qry[i], y_qry[i],self.update_steps,nets = net,images=False)
            g_loss_q += g_loss_q_tmp
            d_loss_q += d_loss_q_tmp
            assert len(corrects_tmp.keys()) == len(corrects.keys())
            for key in corrects.keys():
                corrects[key] += corrects_tmp[key]
            
        # end of all tasks
        # sum over final losses on query set across all tasks
        g_loss_q /= tasks_per_batch
        self.meta_gen_optim.zero_grad()
        g_loss_q.backward()
        self.meta_gen_optim.step()        

        # optimize theta parameters
        d_loss_q /= tasks_per_batch
        self.meta_d_optim.zero_grad()
        d_loss_q.backward()
        self.meta_d_optim.step()
        
        accs = {}
        accs["query_nway"] = corrects["query_nway"] / (tasks_per_batch * query_sz)
        accs["predict_other"] = corrects["predict_other"] / (tasks_per_batch * query_sz)
        accs["gen_discrim"] = corrects["gen_discrim"] / (tasks_per_batch * self.qry_gen_num)
        return accs,d_loss_q,g_loss_q

    def finetunning(self, x_spt, y_spt, x_qry, y_qry):
        """

        :param x_spt:   [support_sz, c_, h, w]
        :param y_spt:   [support_sz]
        :param x_qry:   [query_sz, c_, h, w]
        :param y_qry:   [query_sz]
        :return:
        """

        support_sz, c_, h, w = x_spt.size()

        assert len(x_spt.shape) == 4

        query_sz = x_qry.size(0)

        # in order to not ruin the state of running_mean/variance and bn_weight/bias
        # we finetunning on the copied model instead of self.net
        
        discrim_net = deepcopy(self.discrim_net)
        generator = deepcopy(self.generator)
        net = [self.discrim_net,self.generator]
        d_loss_q,g_loss_q, corrects, imgs = self.single_task_forward(x_spt, y_spt, x_qry, y_qry,self.update_steps_test, nets=net,images=True)

        del discrim_net
        
        accs["query_nway"] = corrects["query_nway"] / (query_sz)
        accs["predict_other"] = corrects["predict_other"] / (query_sz)
        accs["gen_discrim"] = corrects["gen_discrim"] / (self.qry_gen_num)

        return accs, imgs,d_loss_q,g_loss_q

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
mamlGAN = Meta(args, discriminator_config, gen_config).to(device)
step = 0
path = args["save_path"]
mkdir_p(path)
best_acc = []

with tqdm.tqdm(initial=step,
                   total=int(args["epoch"])) as pbar_train:
    for _ in range(args["epoch"] * args["tasks_per_batch"]//6000):
        train_dataloader = DataLoader(train_data_generator, args["tasks_per_batch"], shuffle=True, num_workers=2, pin_memory=True)

        for _, (x_spt, y_spt, x_qry, y_qry) in enumerate(train_dataloader):
            tmp_x_spt, tmp_y_spt, tmp_x_qry, tmp_y_qry = x_spt.squeeze(0), y_spt.squeeze(0), \
                                         x_qry.squeeze(0), y_qry.squeeze(0)
            x_spt, y_spt, x_qry, y_qry = x_spt.to(device), y_spt.to(device), x_qry.to(device), y_qry.to(device)

            accs,d_loss,g_loss = mamlGAN(x_spt, y_spt, x_qry, y_qry,step)
            writer.add_scalar('Loss/train_d_loss', d_loss, step)
            writer.add_scalar('Loss/train_g_loss', g_loss, step)
            writer.add_scalar('Accuracy/query_nway', accs["query_nway"][-1], step)
            writer.add_scalar('Accuracy/gen_discrim', accs["gen_discrim"][-1], step)
            writer.add_scalar('Accuracy/predict_other', accs["predict_other"][-1],step)
            if step % 100 == 0:
                print("step " + str(step))
                print('d loss:',d_loss.item())
                print('g loss:',g_loss.item())
                print("accs",accs)


            if step % 300 == 0:  # evaluation
                db_test = DataLoader(test_data_generator, 1, shuffle=True, num_workers=4, pin_memory=True)
                accs_all_test = []
                imgs_all_test = []
                d_loss_all_test = []
                g_loss_all_test = []
                for x_spt, y_spt, x_qry, y_qry in db_test:
                    tmp_x_spt, tmp_y_spt, tmp_x_qry, tmp_y_qry = x_spt.squeeze(0), y_spt.squeeze(0), \
                                                 x_qry.squeeze(0), y_qry.squeeze(0)
                    x_spt, y_spt, x_qry, y_qry = x_spt.squeeze(0).to(device), y_spt.squeeze(0).to(device), \
                                                 x_qry.squeeze(0).to(device), y_qry.squeeze(0).to(device)
                    # accs, d_loss = mamlGAN.finetunning(x_spt, y_spt, x_qry, y_qry)
                    accs, imgs,d_loss,g_loss = mamlGAN.finetunning(x_spt, y_spt, x_qry, y_qry)


                    accs_all_test.append(accs)
                    imgs_all_test.append(imgs.cpu().detach().numpy())
                    d_loss_all_test.append(d_loss.item())
                    g_loss_all_test.append(g_loss.item())

                imgs_all_test = np.array(imgs_all_test)
                # [b, update_step+1]
                # accs = np.array(accs_all_test).mean(axis=0).astype(np.float16)
                d_loss = np.mean(np.array(d_loss_all_test))
                g_loss = np.mean(np.array(g_loss_all_test))

                print('d loss:',d_loss)
                print('g loss:',g_loss)
                print('Test acc:', accs)    

                writer.add_scalar('Loss/test_d_loss', d_loss, step)
                writer.add_scalar('Loss/test_g_loss', g_loss, step)
                writer.add_scalar('Accuracy/test_query_nway', accs["query_nway"][-1], step)
                writer.add_scalar('Accuracy/test_gen_discrim', accs["gen_discrim"][-1], step)
                writer.add_scalar('Accuracy/test_predict_other', accs["predict_other"][-1],step)
                if not len(best_acc):
                    best_acc = accs
                    best_epoch = step
                    torch.save({'model_state_dict': mamlGAN.state_dict()}, "save_models/" + path + "/best.pth")
                else:
                    if max(accs) > max(best_acc):
                        best_acc = accs
                        best_epoch = step
                        torch.save({'model_state_dict': mamlGAN.state_dict()}, "save_models/" + path + "/best.pth")
                torch.save({'model_state_dict': mamlGAN.state_dict()}, "save_models/" + path + "/model_step" + str(step) + ".pth")

                save_imgs(path, imgs_all_test, step)

            step = step + 1
            pbar_train.update(1)
# Out:
#   0%|          | 0/96000 [00:00<?, ?it/s]
# step 0
# d loss: 2.7871816158294678
# g loss: 4.492897987365723
# accs {'query_nway': array([0.19733333, 0.38666667, 0.39733333]), 'predict_other': array([0.26666667, 0.456     , 0.512     ]), 'gen_discrim': array([0.992, 1.   , 1.   ])}
# d loss: 3.638828393816948
# g loss: 3.31821082085371
# Test acc: {'query_nway': array([0.18666667, 0.33333333, 0.36      ]), 'predict_other': array([0.01333333, 0.54666667, 0.78666667]), 'gen_discrim': array([0.2, 1. , 1. ])}
# step 100
# d loss: 1.5911238193511963
# g loss: 3.59783673286438
# accs {'query_nway': array([0.18133333, 0.29866667, 0.40266667]), 'predict_other': array([0.        , 0.        , 0.00533333]), 'gen_discrim': array([0.008, 0.984, 0.984])}
# step 200
# d loss: 3.4532086849212646
# g loss: 2.2556636333465576
# accs {'query_nway': array([0.16      , 0.30133333, 0.32266667]), 'predict_other': array([0.   , 0.   , 0.296]), 'gen_discrim': array([0.  , 0.76, 0.76])}
# step 300
# d loss: 2.161689519882202
# g loss: 2.835162401199341
# accs {'query_nway': array([0.19733333, 0.29066667, 0.31466667]), 'predict_other': array([0.        , 0.00266667, 0.19466667]), 'gen_discrim': array([0.   , 0.872, 0.872])}
# d loss: 2.377782106399536
# g loss: 1.6268895015120506
# Test acc: {'query_nway': array([0.17333333, 0.2       , 0.30666667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0.  , 0.44, 0.44])}
# step 400
# d loss: 3.4769680500030518
# g loss: 0.7369475364685059
# accs {'query_nway': array([0.18666667, 0.216     , 0.256     ]), 'predict_other': array([0.        , 0.        , 0.13066667]), 'gen_discrim': array([0.   , 0.608, 0.608])}
# step 500
# d loss: 2.8127095699310303
# g loss: 0.8614171147346497
# accs {'query_nway': array([0.22666667, 0.30133333, 0.34133333]), 'predict_other': array([0.        , 0.        , 0.09866667]), 'gen_discrim': array([0.   , 0.688, 0.688])}
# step 600
# d loss: 2.6022121906280518
# g loss: 3.135756492614746
# accs {'query_nway': array([0.17866667, 0.25066667, 0.312     ]), 'predict_other': array([0.  , 0.  , 0.64]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.3343329250812532
# g loss: 1.9436406023800372
# Test acc: {'query_nway': array([0.2       , 0.25333333, 0.28      ]), 'predict_other': array([0.        , 0.        , 0.82666667]), 'gen_discrim': array([0., 1., 1.])}
# step 700
# d loss: 2.6717236042022705
# g loss: 1.154213309288025
# accs {'query_nway': array([0.21066667, 0.224     , 0.26666667]), 'predict_other': array([0.        , 0.        , 0.03466667]), 'gen_discrim': array([0.   , 0.888, 0.888])}
# step 800
# d loss: 2.8019378185272217
# g loss: 2.3455562591552734
# accs {'query_nway': array([0.192, 0.32 , 0.32 ]), 'predict_other': array([0.   , 0.   , 0.624]), 'gen_discrim': array([0.  , 0.96, 0.96])}
# step 900
# d loss: 2.200935125350952
# g loss: 1.8437601327896118
# accs {'query_nway': array([0.20533333, 0.34933333, 0.448     ]), 'predict_other': array([0.   , 0.   , 0.528]), 'gen_discrim': array([0.   , 0.968, 0.968])}
# d loss: 2.6693365454673765
# g loss: 1.3376775071024896
# Test acc: {'query_nway': array([0.17333333, 0.38666667, 0.56      ]), 'predict_other': array([0.        , 0.        , 0.98666667]), 'gen_discrim': array([0., 1., 1.])}
# step 1000
# d loss: 2.8400416374206543
# g loss: 3.2649731636047363
# accs {'query_nway': array([0.17333333, 0.296     , 0.296     ]), 'predict_other': array([0.        , 0.        , 0.67466667]), 'gen_discrim': array([0.04, 1.  , 1.  ])}
# step 1100
# d loss: 1.9632705450057983
# g loss: 2.3455111980438232
# accs {'query_nway': array([0.18933333, 0.17333333, 0.27466667]), 'predict_other': array([0.        , 0.        , 0.19466667]), 'gen_discrim': array([0.   , 0.968, 0.968])}
# step 1200
# d loss: 2.564079761505127
# g loss: 1.9270544052124023
# accs {'query_nway': array([0.16533333, 0.26133333, 0.29866667]), 'predict_other': array([0.        , 0.        , 0.70133333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.580053651332855
# g loss: 1.9390927746891975
# Test acc: {'query_nway': array([0.2       , 0.28      , 0.26666667]), 'predict_other': array([0.        , 0.        , 0.42666667]), 'gen_discrim': array([0.  , 0.92, 0.92])}
# step 1300
# d loss: 2.1063320636749268
# g loss: 1.9034137725830078
# accs {'query_nway': array([0.21066667, 0.224     , 0.24      ]), 'predict_other': array([0.        , 0.        , 0.20266667]), 'gen_discrim': array([0.   , 0.968, 0.968])}
# step 1400
# d loss: 2.303039312362671
# g loss: 1.3434542417526245
# accs {'query_nway': array([0.22933333, 0.28533333, 0.352     ]), 'predict_other': array([0.   , 0.   , 0.312]), 'gen_discrim': array([0.   , 0.928, 0.928])}
# step 1500
# d loss: 1.6088829040527344
# g loss: 3.4057540893554688
# accs {'query_nway': array([0.23733333, 0.304     , 0.36533333]), 'predict_other': array([0.        , 0.        , 0.00533333]), 'gen_discrim': array([0.36, 1.  , 1.  ])}
# d loss: 1.652781431376934
# g loss: 3.421855568140745
# Test acc: {'query_nway': array([0.29333333, 0.38666667, 0.44      ]), 'predict_other': array([0.        , 0.        , 0.01333333]), 'gen_discrim': array([0.36, 0.96, 0.96])}
# step 1600
# d loss: 2.876753330230713
# g loss: 1.9708575010299683
# accs {'query_nway': array([0.208     , 0.288     , 0.22933333]), 'predict_other': array([0.        , 0.        , 0.57333333]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# step 1700
# d loss: 1.9321922063827515
# g loss: 3.3922340869903564
# accs {'query_nway': array([0.25333333, 0.36533333, 0.39466667]), 'predict_other': array([0.        , 0.        , 0.44266667]), 'gen_discrim': array([0., 1., 1.])}
# step 1800
# d loss: 2.828240156173706
# g loss: 0.46239715814590454
# accs {'query_nway': array([0.16266667, 0.32      , 0.37866667]), 'predict_other': array([0.        , 0.        , 0.10666667]), 'gen_discrim': array([0.   , 0.752, 0.752])}
# d loss: 3.269019216299057
# g loss: 2.4316141605377197
# Test acc: {'query_nway': array([0.16      , 0.36      , 0.41333333]), 'predict_other': array([0.  , 0.  , 0.96]), 'gen_discrim': array([0., 1., 1.])}
# step 1900
# d loss: 2.287158727645874
# g loss: 2.8396263122558594
# accs {'query_nway': array([0.27466667, 0.37333333, 0.41866667]), 'predict_other': array([0.        , 0.00266667, 0.28266667]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# step 2000
# d loss: 1.7605940103530884
# g loss: 3.616905689239502
# accs {'query_nway': array([0.17066667, 0.23733333, 0.30666667]), 'predict_other': array([0.   , 0.   , 0.184]), 'gen_discrim': array([0.008, 1.   , 1.   ])}
# step 2100
# d loss: 2.1621880531311035
# g loss: 1.22799813747406
# accs {'query_nway': array([0.25866667, 0.32      , 0.4       ]), 'predict_other': array([0.        , 0.        , 0.04266667]), 'gen_discrim': array([0.   , 0.856, 0.856])}
# d loss: 2.9187796130776404
# g loss: 2.3816526994109153
# Test acc: {'query_nway': array([0.16      , 0.24      , 0.34666667]), 'predict_other': array([0., 0., 1.]), 'gen_discrim': array([0., 1., 1.])}
# step 2200
# d loss: 2.4071290493011475
# g loss: 1.1491219997406006
# accs {'query_nway': array([0.16      , 0.25333333, 0.288     ]), 'predict_other': array([0.        , 0.        , 0.26666667]), 'gen_discrim': array([0., 1., 1.])}
# step 2300
# d loss: 2.204953193664551
# g loss: 1.1555181741714478
# accs {'query_nway': array([0.21333333, 0.31466667, 0.352     ]), 'predict_other': array([0.        , 0.        , 0.16266667]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# step 2400
# d loss: 2.65635347366333
# g loss: 0.5970249176025391
# accs {'query_nway': array([0.256     , 0.31466667, 0.34666667]), 'predict_other': array([0.        , 0.        , 0.01333333]), 'gen_discrim': array([0.   , 0.768, 0.768])}
# d loss: 2.4644717141985892
# g loss: 2.920633281767368
# Test acc: {'query_nway': array([0.16      , 0.22666667, 0.30666667]), 'predict_other': array([0., 0., 1.]), 'gen_discrim': array([0.04, 1.  , 1.  ])}
# step 2500
# d loss: 2.3868229389190674
# g loss: 1.3593084812164307
# accs {'query_nway': array([0.232     , 0.328     , 0.37866667]), 'predict_other': array([0.        , 0.        , 0.38933333]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# step 2600
# d loss: 2.1022937297821045
# g loss: 1.0830901861190796
# accs {'query_nway': array([0.18933333, 0.288     , 0.37066667]), 'predict_other': array([0.   , 0.   , 0.024]), 'gen_discrim': array([0.  , 0.96, 0.96])}
# step 2700
# d loss: 2.0026681423187256
# g loss: 2.827763080596924
# accs {'query_nway': array([0.17866667, 0.23466667, 0.31466667]), 'predict_other': array([0.        , 0.        , 0.21333333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 1.7282427936792373
# g loss: 2.2733975179493426
# Test acc: {'query_nway': array([0.10666667, 0.24      , 0.36      ]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 2800
# d loss: 2.3368289470672607
# g loss: 2.248971700668335
# accs {'query_nway': array([0.22666667, 0.23733333, 0.28266667]), 'predict_other': array([0.        , 0.        , 0.50666667]), 'gen_discrim': array([0., 1., 1.])}
# step 2900
# d loss: 2.675795793533325
# g loss: 3.0958313941955566
# accs {'query_nway': array([0.20266667, 0.27466667, 0.28533333]), 'predict_other': array([0.        , 0.        , 0.69866667]), 'gen_discrim': array([0.048, 1.   , 1.   ])}
# step 3000
# d loss: 1.8930758237838745
# g loss: 2.259164333343506
# accs {'query_nway': array([0.23466667, 0.29866667, 0.35733333]), 'predict_other': array([0.        , 0.        , 0.24533333]), 'gen_discrim': array([0.   , 0.976, 0.976])}
# d loss: 2.7429522305727003
# g loss: 2.0719507150352
# Test acc: {'query_nway': array([0.28      , 0.38666667, 0.4       ]), 'predict_other': array([0.        , 0.        , 0.93333333]), 'gen_discrim': array([0., 1., 1.])}
# step 3100
# d loss: 2.562610387802124
# g loss: 2.872692823410034
# accs {'query_nway': array([0.216     , 0.27733333, 0.328     ]), 'predict_other': array([0.   , 0.   , 0.496]), 'gen_discrim': array([0., 1., 1.])}
# step 3200
# d loss: 2.343477249145508
# g loss: 0.8232706189155579
# accs {'query_nway': array([0.17866667, 0.296     , 0.32533333]), 'predict_other': array([0.        , 0.        , 0.13066667]), 'gen_discrim': array([0.   , 0.952, 0.952])}
# step 3300
# d loss: 2.419748306274414
# g loss: 1.8929191827774048
# accs {'query_nway': array([0.26933333, 0.31466667, 0.312     ]), 'predict_other': array([0.        , 0.        , 0.49333333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.668675537407398
# g loss: 0.7889352119527757
# Test acc: {'query_nway': array([0.34666667, 0.56      , 0.62666667]), 'predict_other': array([0.        , 0.        , 0.77333333]), 'gen_discrim': array([0., 1., 1.])}
# step 3400
# d loss: 1.8934310674667358
# g loss: 1.874362587928772
# accs {'query_nway': array([0.23733333, 0.34933333, 0.4       ]), 'predict_other': array([0.        , 0.        , 0.13066667]), 'gen_discrim': array([0.   , 0.896, 0.896])}
# step 3500
# d loss: 2.727416753768921
# g loss: 1.4823464155197144
# accs {'query_nway': array([0.20266667, 0.28      , 0.296     ]), 'predict_other': array([0.   , 0.   , 0.352]), 'gen_discrim': array([0.   , 0.824, 0.824])}
# step 3600
# d loss: 2.618396520614624
# g loss: 1.0065629482269287
# accs {'query_nway': array([0.27733333, 0.424     , 0.424     ]), 'predict_other': array([0.        , 0.        , 0.43466667]), 'gen_discrim': array([0.   , 0.768, 0.768])}
# d loss: 3.3742869436740874
# g loss: 2.9087894510477783
# Test acc: {'query_nway': array([0.18666667, 0.29333333, 0.36      ]), 'predict_other': array([0.        , 0.        , 0.97333333]), 'gen_discrim': array([0., 1., 1.])}
# step 3700
# d loss: 1.802789330482483
# g loss: 2.808519124984741
# accs {'query_nway': array([0.17866667, 0.34666667, 0.448     ]), 'predict_other': array([0.  , 0.  , 0.24]), 'gen_discrim': array([0., 1., 1.])}
# step 3800
# d loss: 2.2930121421813965
# g loss: 1.0944305658340454
# accs {'query_nway': array([0.18666667, 0.29866667, 0.38133333]), 'predict_other': array([0.        , 0.        , 0.27466667]), 'gen_discrim': array([0.   , 0.744, 0.744])}
# step 3900
# d loss: 1.8178367614746094
# g loss: 3.1189160346984863
# accs {'query_nway': array([0.18133333, 0.296     , 0.36533333]), 'predict_other': array([0.   , 0.   , 0.288]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.7365224957466125
# g loss: 2.1758166823536156
# Test acc: {'query_nway': array([0.22666667, 0.29333333, 0.6       ]), 'predict_other': array([0.  , 0.  , 0.96]), 'gen_discrim': array([0. , 0.8, 0.8])}
# step 4000
# d loss: 1.9406664371490479
# g loss: 3.19490909576416
# accs {'query_nway': array([0.22666667, 0.32533333, 0.41333333]), 'predict_other': array([0.        , 0.00266667, 0.20533333]), 'gen_discrim': array([0., 1., 1.])}
# step 4100
# d loss: 2.0140163898468018
# g loss: 3.2975616455078125
# accs {'query_nway': array([0.15733333, 0.22133333, 0.24      ]), 'predict_other': array([0.        , 0.        , 0.39466667]), 'gen_discrim': array([0., 1., 1.])}
# step 4200
# d loss: 2.0301220417022705
# g loss: 1.6021543741226196
# accs {'query_nway': array([0.208     , 0.336     , 0.35466667]), 'predict_other': array([0.   , 0.   , 0.208]), 'gen_discrim': array([0.   , 0.864, 0.864])}
# d loss: 1.9851670041680336
# g loss: 2.2719855457544327
# Test acc: {'query_nway': array([0.29333333, 0.56      , 0.62666667]), 'predict_other': array([0.  , 0.  , 0.64]), 'gen_discrim': array([0., 1., 1.])}
# step 4300
# d loss: 2.198361873626709
# g loss: 3.8742756843566895
# accs {'query_nway': array([0.17066667, 0.26666667, 0.31466667]), 'predict_other': array([0.   , 0.   , 0.352]), 'gen_discrim': array([0., 1., 1.])}
# step 4400
# d loss: 2.3952207565307617
# g loss: 1.9755083322525024
# accs {'query_nway': array([0.22933333, 0.22933333, 0.29866667]), 'predict_other': array([0.        , 0.        , 0.53866667]), 'gen_discrim': array([0.   , 0.968, 0.968])}
# step 4500
# d loss: 1.9942387342453003
# g loss: 1.3339698314666748
# accs {'query_nway': array([0.13066667, 0.336     , 0.496     ]), 'predict_other': array([0.        , 0.        , 0.15733333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 3.249338264763355
# g loss: 3.3258974669501185
# Test acc: {'query_nway': array([0.22666667, 0.21333333, 0.14666667]), 'predict_other': array([0.        , 0.        , 0.98666667]), 'gen_discrim': array([0., 1., 1.])}
# step 4600
# d loss: 2.0150787830352783
# g loss: 2.1763367652893066
# accs {'query_nway': array([0.20266667, 0.31466667, 0.41066667]), 'predict_other': array([0.        , 0.        , 0.24533333]), 'gen_discrim': array([0.   , 0.688, 0.688])}
# step 4700
# d loss: 2.3957457542419434
# g loss: 3.2843453884124756
# accs {'query_nway': array([0.19466667, 0.21866667, 0.21066667]), 'predict_other': array([0.        , 0.        , 0.55466667]), 'gen_discrim': array([0., 1., 1.])}
# step 4800
# d loss: 2.1852867603302
# g loss: 2.402066469192505
# accs {'query_nway': array([0.30133333, 0.34133333, 0.352     ]), 'predict_other': array([0.        , 0.        , 0.24266667]), 'gen_discrim': array([0.   , 0.768, 0.768])}
# d loss: 2.8018035769462584
# g loss: 2.6493594244122507
# Test acc: {'query_nway': array([0.16      , 0.21333333, 0.36      ]), 'predict_other': array([0.        , 0.        , 0.90666667]), 'gen_discrim': array([0.  , 0.88, 0.88])}
# step 4900
# d loss: 1.8518997430801392
# g loss: 2.0441038608551025
# accs {'query_nway': array([0.17066667, 0.34933333, 0.40266667]), 'predict_other': array([0.        , 0.        , 0.17866667]), 'gen_discrim': array([0., 1., 1.])}
# step 5000
# d loss: 1.6880019903182983
# g loss: 2.3216567039489746
# accs {'query_nway': array([0.184     , 0.352     , 0.42933333]), 'predict_other': array([0.        , 0.        , 0.00533333]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# step 5100
# d loss: 1.804864764213562
# g loss: 2.489940643310547
# accs {'query_nway': array([0.232     , 0.38933333, 0.41066667]), 'predict_other': array([0.        , 0.        , 0.21866667]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.3685638293623925
# g loss: 2.103528466820717
# Test acc: {'query_nway': array([0.17333333, 0.36      , 0.29333333]), 'predict_other': array([0.        , 0.        , 0.25333333]), 'gen_discrim': array([0., 1., 1.])}
# step 5200
# d loss: 2.757337808609009
# g loss: 3.241626024246216
# accs {'query_nway': array([0.25066667, 0.33333333, 0.312     ]), 'predict_other': array([0.        , 0.        , 0.74133333]), 'gen_discrim': array([0., 1., 1.])}
# step 5300
# d loss: 1.7943788766860962
# g loss: 2.5645296573638916
# accs {'query_nway': array([0.21866667, 0.41066667, 0.45066667]), 'predict_other': array([0.        , 0.        , 0.30133333]), 'gen_discrim': array([0., 1., 1.])}
# step 5400
# d loss: 1.6070975065231323
# g loss: 3.2745754718780518
# accs {'query_nway': array([0.19733333, 0.31733333, 0.376     ]), 'predict_other': array([0.        , 0.        , 0.02933333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 1.6492874786257743
# g loss: 3.296210226416588
# Test acc: {'query_nway': array([0.13333333, 0.34666667, 0.37333333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 5500
# d loss: 1.4710941314697266
# g loss: 3.741344928741455
# accs {'query_nway': array([0.20533333, 0.38133333, 0.46133333]), 'predict_other': array([0.   , 0.   , 0.008]), 'gen_discrim': array([0., 1., 1.])}
# step 5600
# d loss: 2.885347843170166
# g loss: 2.681689500808716
# accs {'query_nway': array([0.216     , 0.23733333, 0.27733333]), 'predict_other': array([0.        , 0.        , 0.42133333]), 'gen_discrim': array([0., 1., 1.])}
# step 5700
# d loss: 1.6569912433624268
# g loss: 2.301220655441284
# accs {'query_nway': array([0.19466667, 0.30933333, 0.36      ]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 1.6370858550071716
# g loss: 2.6554363168776036
# Test acc: {'query_nway': array([0.08      , 0.13333333, 0.25333333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 5800
# d loss: 1.744640588760376
# g loss: 2.477872371673584
# accs {'query_nway': array([0.208     , 0.32      , 0.33333333]), 'predict_other': array([0.   , 0.   , 0.104]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# step 5900
# d loss: 1.599305510520935
# g loss: 3.6733994483947754
# accs {'query_nway': array([0.17866667, 0.312     , 0.41333333]), 'predict_other': array([0.   , 0.   , 0.152]), 'gen_discrim': array([0., 1., 1.])}
# step 6000
# d loss: 2.0221784114837646
# g loss: 2.3603856563568115
# accs {'query_nway': array([0.14933333, 0.32      , 0.39733333]), 'predict_other': array([0.        , 0.        , 0.20266667]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# d loss: 1.9938528075814248
# g loss: 2.690209849923849
# Test acc: {'query_nway': array([0.16, 0.12, 0.28]), 'predict_other': array([0., 0., 1.]), 'gen_discrim': array([0., 1., 1.])}
# step 6100
# d loss: 2.0798442363739014
# g loss: 2.0266642570495605
# accs {'query_nway': array([0.21333333, 0.25866667, 0.33866667]), 'predict_other': array([0.   , 0.   , 0.272]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 6200
# d loss: 2.2913658618927
# g loss: 2.91656494140625
# accs {'query_nway': array([0.224     , 0.32533333, 0.36533333]), 'predict_other': array([0.        , 0.        , 0.33866667]), 'gen_discrim': array([0.008, 1.   , 1.   ])}
# step 6300
# d loss: 1.9191750288009644
# g loss: 2.265611410140991
# accs {'query_nway': array([0.208     , 0.25066667, 0.336     ]), 'predict_other': array([0.   , 0.   , 0.032]), 'gen_discrim': array([0.   , 0.944, 0.944])}
# d loss: 2.6543229848146437
# g loss: 3.21325004696846
# Test acc: {'query_nway': array([0.21333333, 0.36      , 0.34666667]), 'predict_other': array([0.        , 0.        , 0.25333333]), 'gen_discrim': array([0., 1., 1.])}
# step 6400
# d loss: 1.9923375844955444
# g loss: 1.8968594074249268
# accs {'query_nway': array([0.20533333, 0.38933333, 0.41333333]), 'predict_other': array([0.   , 0.   , 0.272]), 'gen_discrim': array([0., 1., 1.])}
# step 6500
# d loss: 1.9372934103012085
# g loss: 1.3407267332077026
# accs {'query_nway': array([0.20533333, 0.32266667, 0.43466667]), 'predict_other': array([0.        , 0.        , 0.00266667]), 'gen_discrim': array([0.   , 0.968, 0.968])}
# step 6600
# d loss: 1.9542354345321655
# g loss: 2.3652584552764893
# accs {'query_nway': array([0.24      , 0.33333333, 0.42933333]), 'predict_other': array([0.        , 0.        , 0.21066667]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.3909580782055855
# g loss: 2.8691098554059864
# Test acc: {'query_nway': array([0.12      , 0.18666667, 0.44      ]), 'predict_other': array([0.  , 0.  , 0.96]), 'gen_discrim': array([0., 1., 1.])}
# step 6700
# d loss: 2.15871000289917
# g loss: 2.282649278640747
# accs {'query_nway': array([0.15466667, 0.30133333, 0.39466667]), 'predict_other': array([0.        , 0.        , 0.26133333]), 'gen_discrim': array([0.   , 0.888, 0.888])}
# step 6800
# d loss: 1.6046791076660156
# g loss: 2.303579092025757
# accs {'query_nway': array([0.19733333, 0.37066667, 0.52533333]), 'predict_other': array([0.   , 0.   , 0.208]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# step 6900
# d loss: 2.164886236190796
# g loss: 1.9262821674346924
# accs {'query_nway': array([0.21333333, 0.27733333, 0.32      ]), 'predict_other': array([0.        , 0.        , 0.31733333]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# d loss: 2.6905534476041795
# g loss: 3.7806013092398643
# Test acc: {'query_nway': array([0.21333333, 0.42666667, 0.50666667]), 'predict_other': array([0.        , 0.        , 0.17333333]), 'gen_discrim': array([0., 1., 1.])}
# step 7000
# d loss: 1.6528176069259644
# g loss: 2.7789738178253174
# accs {'query_nway': array([0.21333333, 0.288     , 0.36266667]), 'predict_other': array([0.        , 0.        , 0.09866667]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 7100
# d loss: 1.6818197965621948
# g loss: 2.9136393070220947
# accs {'query_nway': array([0.21866667, 0.32533333, 0.39733333]), 'predict_other': array([0.        , 0.        , 0.16533333]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# step 7200
# d loss: 1.8572670221328735
# g loss: 3.4294240474700928
# accs {'query_nway': array([0.19466667, 0.32      , 0.48266667]), 'predict_other': array([0.        , 0.        , 0.38933333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.66232842952013
# g loss: 1.92232815772295
# Test acc: {'query_nway': array([0.22666667, 0.29333333, 0.28      ]), 'predict_other': array([0.  , 0.  , 0.92]), 'gen_discrim': array([0., 1., 1.])}
# step 7300
# d loss: 1.6435765027999878
# g loss: 2.679409980773926
# accs {'query_nway': array([0.19733333, 0.34666667, 0.408     ]), 'predict_other': array([0.        , 0.        , 0.07733333]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 7400
# d loss: 1.7726322412490845
# g loss: 4.1566386222839355
# accs {'query_nway': array([0.19466667, 0.30933333, 0.376     ]), 'predict_other': array([0. , 0. , 0.2]), 'gen_discrim': array([0., 1., 1.])}
# step 7500
# d loss: 2.058034896850586
# g loss: 1.2876887321472168
# accs {'query_nway': array([0.2       , 0.34666667, 0.488     ]), 'predict_other': array([0.        , 0.        , 0.06133333]), 'gen_discrim': array([0.   , 0.944, 0.944])}
# d loss: 2.7190962970256805
# g loss: 4.764470566809178
# Test acc: {'query_nway': array([0.2       , 0.37333333, 0.52      ]), 'predict_other': array([0., 0., 1.]), 'gen_discrim': array([0., 1., 1.])}
# step 7600
# d loss: 1.769971489906311
# g loss: 3.0664074420928955
# accs {'query_nway': array([0.20533333, 0.27733333, 0.392     ]), 'predict_other': array([0.   , 0.   , 0.256]), 'gen_discrim': array([0., 1., 1.])}
# step 7700
# d loss: 1.8228052854537964
# g loss: 3.073059558868408
# accs {'query_nway': array([0.19733333, 0.30933333, 0.384     ]), 'predict_other': array([0.   , 0.   , 0.184]), 'gen_discrim': array([0., 1., 1.])}
# step 7800
# d loss: 2.121642827987671
# g loss: 2.1797845363616943
# accs {'query_nway': array([0.20533333, 0.248     , 0.34666667]), 'predict_other': array([0.        , 0.        , 0.19733333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 1.5077416628599167
# g loss: 3.7228890255093576
# Test acc: {'query_nway': array([0.2       , 0.52      , 0.74666667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 7900
# d loss: 1.529452919960022
# g loss: 2.3071789741516113
# accs {'query_nway': array([0.20533333, 0.41066667, 0.48      ]), 'predict_other': array([0.   , 0.   , 0.008]), 'gen_discrim': array([0., 1., 1.])}
# step 8000
# d loss: 2.153564929962158
# g loss: 2.5075056552886963
# accs {'query_nway': array([0.17333333, 0.26133333, 0.39733333]), 'predict_other': array([0.        , 0.        , 0.38933333]), 'gen_discrim': array([0.  , 0.96, 0.96])}
# step 8100
# d loss: 1.8310531377792358
# g loss: 4.9569807052612305
# accs {'query_nway': array([0.192, 0.288, 0.44 ]), 'predict_other': array([0.        , 0.        , 0.36533333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 1.9064780488610267
# g loss: 2.3442096376791595
# Test acc: {'query_nway': array([0.22666667, 0.4       , 0.42666667]), 'predict_other': array([0.  , 0.  , 0.08]), 'gen_discrim': array([0., 1., 1.])}
# step 8200
# d loss: 1.7377833127975464
# g loss: 2.0450174808502197
# accs {'query_nway': array([0.20533333, 0.33866667, 0.44533333]), 'predict_other': array([0.        , 0.        , 0.05333333]), 'gen_discrim': array([0.  , 0.92, 0.92])}
# step 8300
# d loss: 1.8456047773361206
# g loss: 5.106204509735107
# accs {'query_nway': array([0.21066667, 0.328     , 0.38133333]), 'predict_other': array([0.   , 0.   , 0.248]), 'gen_discrim': array([0.024, 1.   , 1.   ])}
# step 8400
# d loss: 1.5074375867843628
# g loss: 2.4538285732269287
# accs {'query_nway': array([0.2       , 0.24533333, 0.488     ]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.4608141109347343
# g loss: 2.0149067636579274
# Test acc: {'query_nway': array([0.10666667, 0.24      , 0.52      ]), 'predict_other': array([0., 0., 1.]), 'gen_discrim': array([0., 1., 1.])}
# step 8500
# d loss: 1.7598797082901
# g loss: 3.0568418502807617
# accs {'query_nway': array([0.19466667, 0.29866667, 0.408     ]), 'predict_other': array([0.  , 0.  , 0.32]), 'gen_discrim': array([0.   , 0.976, 0.976])}
# step 8600
# d loss: 1.8530391454696655
# g loss: 1.649438738822937
# accs {'query_nway': array([0.20266667, 0.29333333, 0.512     ]), 'predict_other': array([0.   , 0.   , 0.048]), 'gen_discrim': array([0., 1., 1.])}
# step 8700
# d loss: 1.9071581363677979
# g loss: 3.2094483375549316
# accs {'query_nway': array([0.2       , 0.29333333, 0.27466667]), 'predict_other': array([0.  , 0.  , 0.24]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# d loss: 2.2681547462940217
# g loss: 3.468851288408041
# Test acc: {'query_nway': array([0.2       , 0.4       , 0.58666667]), 'predict_other': array([0.        , 0.        , 0.74666667]), 'gen_discrim': array([0., 1., 1.])}
# step 8800
# d loss: 2.2599804401397705
# g loss: 1.758405327796936
# accs {'query_nway': array([0.17066667, 0.31733333, 0.408     ]), 'predict_other': array([0.   , 0.   , 0.088]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 8900
# d loss: 2.0092105865478516
# g loss: 5.158578395843506
# accs {'query_nway': array([0.19466667, 0.26666667, 0.272     ]), 'predict_other': array([0.   , 0.   , 0.304]), 'gen_discrim': array([0., 1., 1.])}
# step 9000
# d loss: 1.9431709051132202
# g loss: 3.623915910720825
# accs {'query_nway': array([0.20266667, 0.31466667, 0.43733333]), 'predict_other': array([0.        , 0.        , 0.45066667]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.6821105554699898
# g loss: 1.0740878785960377
# Test acc: {'query_nway': array([0.2       , 0.22666667, 0.44      ]), 'predict_other': array([0.        , 0.        , 0.17333333]), 'gen_discrim': array([0.  , 0.92, 0.92])}
# step 9100
# d loss: 2.0304784774780273
# g loss: 1.288494348526001
# accs {'query_nway': array([0.216     , 0.34666667, 0.512     ]), 'predict_other': array([0.        , 0.        , 0.01333333]), 'gen_discrim': array([0.   , 0.264, 0.264])}
# step 9200
# d loss: 1.9440298080444336
# g loss: 1.4697102308273315
# accs {'query_nway': array([0.21333333, 0.336     , 0.504     ]), 'predict_other': array([0.   , 0.   , 0.064]), 'gen_discrim': array([0.   , 0.648, 0.648])}
# step 9300
# d loss: 1.8114862442016602
# g loss: 4.188977241516113
# accs {'query_nway': array([0.18933333, 0.29333333, 0.38666667]), 'predict_other': array([0.        , 0.        , 0.34933333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.617866624891758
# g loss: 2.191605696082115
# Test acc: {'query_nway': array([0.2 , 0.4 , 0.68]), 'predict_other': array([0.        , 0.        , 0.42666667]), 'gen_discrim': array([0.  , 0.72, 0.72])}
# step 9400
# d loss: 2.116590976715088
# g loss: 1.7030426263809204
# accs {'query_nway': array([0.18666667, 0.304     , 0.41866667]), 'predict_other': array([0.   , 0.   , 0.216]), 'gen_discrim': array([0.   , 0.744, 0.744])}
# step 9500
# d loss: 1.8325623273849487
# g loss: 1.9500048160552979
# accs {'query_nway': array([0.232     , 0.32266667, 0.44      ]), 'predict_other': array([0.   , 0.   , 0.024]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 9600
# d loss: 1.87917160987854
# g loss: 1.9677667617797852
# accs {'query_nway': array([0.192     , 0.256     , 0.38133333]), 'predict_other': array([0.        , 0.        , 0.22666667]), 'gen_discrim': array([0.   , 0.968, 0.968])}
# d loss: 2.235431155562401
# g loss: 2.805359162390232
# Test acc: {'query_nway': array([0.2       , 0.32      , 0.37333333]), 'predict_other': array([0.  , 0.  , 0.48]), 'gen_discrim': array([0., 1., 1.])}
# step 9700
# d loss: 1.2002174854278564
# g loss: 3.0835158824920654
# accs {'query_nway': array([0.20266667, 0.46933333, 0.608     ]), 'predict_other': array([0.        , 0.        , 0.00266667]), 'gen_discrim': array([0., 1., 1.])}
# step 9800
# d loss: 2.067253828048706
# g loss: 3.179400682449341
# accs {'query_nway': array([0.208     , 0.37866667, 0.45866667]), 'predict_other': array([0.   , 0.   , 0.352]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 9900
# d loss: 1.6786936521530151
# g loss: 2.781883955001831
# accs {'query_nway': array([0.2       , 0.35466667, 0.38933333]), 'predict_other': array([0.   , 0.   , 0.128]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.244899334013462
# g loss: 2.5157917514443398
# Test acc: {'query_nway': array([0.18666667, 0.4       , 0.52      ]), 'predict_other': array([0.  , 0.  , 0.76]), 'gen_discrim': array([0., 1., 1.])}
# step 10000
# d loss: 1.4347963333129883
# g loss: 3.8263070583343506
# accs {'query_nway': array([0.19466667, 0.43466667, 0.49066667]), 'predict_other': array([0.        , 0.        , 0.06933333]), 'gen_discrim': array([0.   , 0.976, 0.976])}
# step 10100
# d loss: 2.8559842109680176
# g loss: 0.7466150522232056
# accs {'query_nway': array([0.19733333, 0.248     , 0.34933333]), 'predict_other': array([0.        , 0.        , 0.06666667]), 'gen_discrim': array([0.  , 0.88, 0.88])}
# step 10200
# d loss: 1.6454695463180542
# g loss: 3.567991256713867
# accs {'query_nway': array([0.20533333, 0.336     , 0.45333333]), 'predict_other': array([0.   , 0.   , 0.184]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# d loss: 1.8384045034646987
# g loss: 3.260112574696541
# Test acc: {'query_nway': array([0.2       , 0.46666667, 0.52      ]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 10300
# d loss: 1.6027679443359375
# g loss: 2.705514907836914
# accs {'query_nway': array([0.19733333, 0.37066667, 0.464     ]), 'predict_other': array([0.  , 0.  , 0.04]), 'gen_discrim': array([0., 1., 1.])}
# step 10400
# d loss: 1.5816301107406616
# g loss: 3.247908353805542
# accs {'query_nway': array([0.144     , 0.25333333, 0.39466667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 10500
# d loss: 1.3960838317871094
# g loss: 3.429079055786133
# accs {'query_nway': array([0.16      , 0.33066667, 0.49066667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 1.6116641283035278
# g loss: 3.5838368803262712
# Test acc: {'query_nway': array([0.2       , 0.29333333, 0.58666667]), 'predict_other': array([0.        , 0.        , 0.77333333]), 'gen_discrim': array([0., 1., 1.])}
# step 10600
# d loss: 2.30202317237854
# g loss: 1.1760162115097046
# accs {'query_nway': array([0.2       , 0.36266667, 0.44266667]), 'predict_other': array([0.        , 0.        , 0.04266667]), 'gen_discrim': array([0., 1., 1.])}
# step 10700
# d loss: 2.0904319286346436
# g loss: 3.2270660400390625
# accs {'query_nway': array([0.24266667, 0.336     , 0.43466667]), 'predict_other': array([0.        , 0.        , 0.21066667]), 'gen_discrim': array([0., 1., 1.])}
# step 10800
# d loss: 1.5888539552688599
# g loss: 2.1648738384246826
# accs {'query_nway': array([0.2       , 0.40533333, 0.544     ]), 'predict_other': array([0.        , 0.        , 0.04266667]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# d loss: 2.3984327360987665
# g loss: 3.7159159913659097
# Test acc: {'query_nway': array([0.14666667, 0.22666667, 0.52      ]), 'predict_other': array([0.        , 0.        , 0.09333333]), 'gen_discrim': array([0., 1., 1.])}
# step 10900
# d loss: 1.3788126707077026
# g loss: 3.458691358566284
# accs {'query_nway': array([0.184     , 0.30666667, 0.50933333]), 'predict_other': array([0.        , 0.        , 0.00266667]), 'gen_discrim': array([0., 1., 1.])}
# step 11000
# d loss: 1.879472017288208
# g loss: 2.8044230937957764
# accs {'query_nway': array([0.19466667, 0.224     , 0.42666667]), 'predict_other': array([0.        , 0.        , 0.15733333]), 'gen_discrim': array([0.008, 1.   , 1.   ])}
# step 11100
# d loss: 1.6312049627304077
# g loss: 2.1275579929351807
# accs {'query_nway': array([0.19466667, 0.34933333, 0.52266667]), 'predict_other': array([0.        , 0.        , 0.12266667]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# d loss: 2.413815151154995
# g loss: 2.8845275700092317
# Test acc: {'query_nway': array([0.2       , 0.29333333, 0.34666667]), 'predict_other': array([0.        , 0.        , 0.10666667]), 'gen_discrim': array([0., 1., 1.])}
# step 11200
# d loss: 2.0552403926849365
# g loss: 4.527259349822998
# accs {'query_nway': array([0.2       , 0.37333333, 0.46133333]), 'predict_other': array([0.   , 0.   , 0.376]), 'gen_discrim': array([0., 1., 1.])}
# step 11300
# d loss: 2.1774044036865234
# g loss: 5.794244289398193
# accs {'query_nway': array([0.17333333, 0.288     , 0.36533333]), 'predict_other': array([0.        , 0.        , 0.46133333]), 'gen_discrim': array([0.008, 1.   , 1.   ])}
# step 11400
# d loss: 1.4703878164291382
# g loss: 2.741389036178589
# accs {'query_nway': array([0.20533333, 0.376     , 0.57333333]), 'predict_other': array([0.   , 0.   , 0.168]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# d loss: 2.7665688410401343
# g loss: 2.3264411205425857
# Test acc: {'query_nway': array([0.18666667, 0.53333333, 0.52      ]), 'predict_other': array([0.  , 0.  , 0.72]), 'gen_discrim': array([0., 1., 1.])}
# step 11500
# d loss: 1.6881119012832642
# g loss: 2.27042555809021
# accs {'query_nway': array([0.22933333, 0.31733333, 0.464     ]), 'predict_other': array([0.        , 0.        , 0.01866667]), 'gen_discrim': array([0.   , 0.904, 0.904])}
# step 11600
# d loss: 1.9672834873199463
# g loss: 2.656027317047119
# accs {'query_nway': array([0.21333333, 0.248     , 0.36      ]), 'predict_other': array([0.        , 0.        , 0.17066667]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 11700
# d loss: 1.9888238906860352
# g loss: 4.153157711029053
# accs {'query_nway': array([0.21866667, 0.304     , 0.39733333]), 'predict_other': array([0.        , 0.        , 0.41066667]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.4301402658224105
# g loss: 2.1874633032828568
# Test acc: {'query_nway': array([0.2       , 0.45333333, 0.68      ]), 'predict_other': array([0.        , 0.        , 0.10666667]), 'gen_discrim': array([0.  , 0.76, 0.76])}
# step 11800
# d loss: 2.260589361190796
# g loss: 4.237194538116455
# accs {'query_nway': array([0.19733333, 0.39733333, 0.46933333]), 'predict_other': array([0.  , 0.  , 0.48]), 'gen_discrim': array([0., 1., 1.])}
# step 11900
# d loss: 1.9525623321533203
# g loss: 3.2531685829162598
# accs {'query_nway': array([0.18933333, 0.33866667, 0.448     ]), 'predict_other': array([0.        , 0.        , 0.40266667]), 'gen_discrim': array([0., 1., 1.])}
# step 12000
# d loss: 2.090634822845459
# g loss: 1.9380205869674683
# accs {'query_nway': array([0.20266667, 0.352     , 0.58933333]), 'predict_other': array([0.        , 0.        , 0.22933333]), 'gen_discrim': array([0.   , 0.968, 0.968])}
# d loss: 3.170024278759956
# g loss: 3.092483025789261
# Test acc: {'query_nway': array([0.09333333, 0.30666667, 0.64      ]), 'predict_other': array([0.        , 0.        , 0.41333333]), 'gen_discrim': array([0.  , 0.88, 0.88])}
# step 12100
# d loss: 1.976852297782898
# g loss: 1.8196510076522827
# accs {'query_nway': array([0.2  , 0.24 , 0.368]), 'predict_other': array([0.   , 0.   , 0.056]), 'gen_discrim': array([0.   , 0.904, 0.904])}
# step 12200
# d loss: 1.5474863052368164
# g loss: 3.7843616008758545
# accs {'query_nway': array([0.19733333, 0.30666667, 0.41066667]), 'predict_other': array([0.        , 0.        , 0.00266667]), 'gen_discrim': array([0.008, 1.   , 1.   ])}
# step 12300
# d loss: 2.32999587059021
# g loss: 1.0271490812301636
# accs {'query_nway': array([0.20533333, 0.32533333, 0.42933333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0. , 0.8, 0.8])}
# d loss: 2.4601468250155447
# g loss: 4.349538873136043
# Test acc: {'query_nway': array([0.21333333, 0.36      , 0.38666667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 12400
# d loss: 1.6504127979278564
# g loss: 2.0932796001434326
# accs {'query_nway': array([0.2       , 0.29066667, 0.49066667]), 'predict_other': array([0.        , 0.        , 0.01066667]), 'gen_discrim': array([0.  , 0.88, 0.88])}
# step 12500
# d loss: 2.015359401702881
# g loss: 2.3055942058563232
# accs {'query_nway': array([0.22133333, 0.344     , 0.38933333]), 'predict_other': array([0.        , 0.        , 0.08266667]), 'gen_discrim': array([0.   , 0.888, 0.888])}
# step 12600
# d loss: 1.6474508047103882
# g loss: 3.1565263271331787
# accs {'query_nway': array([0.208     , 0.29866667, 0.34933333]), 'predict_other': array([0.        , 0.        , 0.01866667]), 'gen_discrim': array([0.   , 0.928, 0.928])}
# d loss: 3.648149201273918
# g loss: 4.575809256732464
# Test acc: {'query_nway': array([0.2       , 0.38666667, 0.32      ]), 'predict_other': array([0.        , 0.        , 0.97333333]), 'gen_discrim': array([0., 1., 1.])}
# step 12700
# d loss: 1.4361246824264526
# g loss: 4.051939010620117
# accs {'query_nway': array([0.2       , 0.44266667, 0.54933333]), 'predict_other': array([0.        , 0.        , 0.17066667]), 'gen_discrim': array([0., 1., 1.])}
# step 12800
# d loss: 1.3828009366989136
# g loss: 3.6506874561309814
# accs {'query_nway': array([0.20533333, 0.35733333, 0.49866667]), 'predict_other': array([0.        , 0.        , 0.00266667]), 'gen_discrim': array([0., 1., 1.])}
# step 12900
# d loss: 2.4959232807159424
# g loss: 4.589354515075684
# accs {'query_nway': array([0.2       , 0.33066667, 0.30666667]), 'predict_other': array([0.        , 0.        , 0.39733333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.1826662376523016
# g loss: 1.0722106837667524
# Test acc: {'query_nway': array([0.2       , 0.30666667, 0.38666667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0.  , 0.92, 0.92])}
# step 13000
# d loss: 2.073215961456299
# g loss: 2.6754024028778076
# accs {'query_nway': array([0.19733333, 0.29066667, 0.38666667]), 'predict_other': array([0.   , 0.   , 0.376]), 'gen_discrim': array([0., 1., 1.])}
# step 13100
# d loss: 1.4527798891067505
# g loss: 3.3863208293914795
# accs {'query_nway': array([0.2       , 0.344     , 0.42933333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 13200
# d loss: 1.7202364206314087
# g loss: 2.461002826690674
# accs {'query_nway': array([0.192     , 0.29333333, 0.368     ]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# d loss: 1.51086745262146
# g loss: 3.851204128563404
# Test acc: {'query_nway': array([0.21333333, 0.48      , 0.57333333]), 'predict_other': array([0.        , 0.        , 0.17333333]), 'gen_discrim': array([0., 1., 1.])}
# step 13300
# d loss: 2.394033193588257
# g loss: 0.8877004981040955
# accs {'query_nway': array([0.19733333, 0.23466667, 0.344     ]), 'predict_other': array([0.   , 0.   , 0.144]), 'gen_discrim': array([0.   , 0.896, 0.896])}
# step 13400
# d loss: 1.584221363067627
# g loss: 3.719686269760132
# accs {'query_nway': array([0.22133333, 0.29066667, 0.472     ]), 'predict_other': array([0.   , 0.   , 0.192]), 'gen_discrim': array([0., 1., 1.])}
# step 13500
# d loss: 4.129445552825928
# g loss: 4.215373992919922
# accs {'query_nway': array([0.224     , 0.28533333, 0.328     ]), 'predict_other': array([0.        , 0.        , 0.78933333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 1.8220629557967185
# g loss: 1.4283564399927855
# Test acc: {'query_nway': array([0.22666667, 0.33333333, 0.45333333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 13600
# d loss: 1.8196051120758057
# g loss: 1.5492454767227173
# accs {'query_nway': array([0.21866667, 0.32266667, 0.456     ]), 'predict_other': array([0.        , 0.        , 0.18133333]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 13700
# d loss: 1.5634902715682983
# g loss: 2.8054587841033936
# accs {'query_nway': array([0.20533333, 0.304     , 0.47466667]), 'predict_other': array([0.        , 0.        , 0.04266667]), 'gen_discrim': array([0., 1., 1.])}
# step 13800
# d loss: 1.842431902885437
# g loss: 1.6680927276611328
# accs {'query_nway': array([0.23733333, 0.29066667, 0.44533333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0.   , 0.888, 0.888])}
# d loss: 1.4680919766426086
# g loss: 4.204525962471962
# Test acc: {'query_nway': array([0.21333333, 0.37333333, 0.4       ]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 13900
# d loss: 1.5214773416519165
# g loss: 2.2794361114501953
# accs {'query_nway': array([0.2       , 0.376     , 0.53066667]), 'predict_other': array([0.   , 0.   , 0.136]), 'gen_discrim': array([0., 1., 1.])}
# step 14000
# d loss: 1.614317536354065
# g loss: 2.2646806240081787
# accs {'query_nway': array([0.2       , 0.30666667, 0.50933333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0.   , 0.976, 0.976])}
# step 14100
# d loss: 1.6394516229629517
# g loss: 3.2153515815734863
# accs {'query_nway': array([0.208     , 0.38133333, 0.50133333]), 'predict_other': array([0.        , 0.        , 0.30133333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 1.6367788322269916
# g loss: 3.3472098454833032
# Test acc: {'query_nway': array([0.18666667, 0.44      , 0.49333333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 14200
# d loss: 1.5920301675796509
# g loss: 3.2593140602111816
# accs {'query_nway': array([0.208     , 0.35733333, 0.48      ]), 'predict_other': array([0.        , 0.        , 0.15733333]), 'gen_discrim': array([0., 1., 1.])}
# step 14300
# d loss: 1.7808927297592163
# g loss: 2.4051101207733154
# accs {'query_nway': array([0.20266667, 0.26933333, 0.46666667]), 'predict_other': array([0. , 0. , 0.2]), 'gen_discrim': array([0., 1., 1.])}
# step 14400
# d loss: 1.5307819843292236
# g loss: 2.8795154094696045
# accs {'query_nway': array([0.17866667, 0.328     , 0.54133333]), 'predict_other': array([0.  , 0.  , 0.08]), 'gen_discrim': array([0.   , 0.944, 0.944])}
# d loss: 1.5794791355729103
# g loss: 2.726660080999136
# Test acc: {'query_nway': array([0.2       , 0.22666667, 0.42666667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 14500
# d loss: 1.3556455373764038
# g loss: 2.3791050910949707
# accs {'query_nway': array([0.19733333, 0.344     , 0.57333333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 14600
# d loss: 1.7118068933486938
# g loss: 2.761298418045044
# accs {'query_nway': array([0.21333333, 0.32      , 0.52266667]), 'predict_other': array([0. , 0. , 0.2]), 'gen_discrim': array([0., 1., 1.])}
# step 14700
# d loss: 1.6191326379776
# g loss: 3.6164357662200928
# accs {'query_nway': array([0.208     , 0.38933333, 0.48      ]), 'predict_other': array([0.        , 0.        , 0.19733333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 1.9841704420745372
# g loss: 3.3029972609132527
# Test acc: {'query_nway': array([0.2       , 0.26666667, 0.56      ]), 'predict_other': array([0.        , 0.        , 0.58666667]), 'gen_discrim': array([0., 1., 1.])}
# step 14800
# d loss: 1.788303017616272
# g loss: 3.5326592922210693
# accs {'query_nway': array([0.20266667, 0.29333333, 0.432     ]), 'predict_other': array([0.   , 0.   , 0.224]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 14900
# d loss: 1.5747467279434204
# g loss: 2.2310636043548584
# accs {'query_nway': array([0.20266667, 0.32      , 0.45066667]), 'predict_other': array([0.        , 0.        , 0.04266667]), 'gen_discrim': array([0.   , 0.968, 0.968])}
# step 15000
# d loss: 1.66230046749115
# g loss: 4.1058149337768555
# accs {'query_nway': array([0.2  , 0.312, 0.48 ]), 'predict_other': array([0.   , 0.   , 0.168]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.2870426759123803
# g loss: 2.0673757867887614
# Test acc: {'query_nway': array([0.26666667, 0.4       , 0.6       ]), 'predict_other': array([0.        , 0.        , 0.73333333]), 'gen_discrim': array([0.  , 0.84, 0.84])}
# step 15100
# d loss: 1.7165882587432861
# g loss: 3.135169506072998
# accs {'query_nway': array([0.21333333, 0.26933333, 0.392     ]), 'predict_other': array([0.        , 0.        , 0.06133333]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# step 15200
# d loss: 1.7167822122573853
# g loss: 5.037208557128906
# accs {'query_nway': array([0.2       , 0.32533333, 0.43466667]), 'predict_other': array([0.        , 0.        , 0.33866667]), 'gen_discrim': array([0., 1., 1.])}
# step 15300
# d loss: 1.254022479057312
# g loss: 6.051153182983398
# accs {'query_nway': array([0.2       , 0.44266667, 0.61866667]), 'predict_other': array([0.   , 0.   , 0.088]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 3.0268450282514094
# g loss: 5.778931194543839
# Test acc: {'query_nway': array([0.2       , 0.34666667, 0.38666667]), 'predict_other': array([0., 0., 1.]), 'gen_discrim': array([0., 1., 1.])}
# step 15400
# d loss: 1.791414499282837
# g loss: 2.9847748279571533
# accs {'query_nway': array([0.19733333, 0.31733333, 0.35466667]), 'predict_other': array([0.   , 0.   , 0.144]), 'gen_discrim': array([0.   , 0.936, 0.936])}
# step 15500
# d loss: 1.640283465385437
# g loss: 5.79003381729126
# accs {'query_nway': array([0.2       , 0.32      , 0.44266667]), 'predict_other': array([0.        , 0.        , 0.18133333]), 'gen_discrim': array([0., 1., 1.])}
# step 15600
# d loss: 2.7309458255767822
# g loss: 6.181012153625488
# accs {'query_nway': array([0.19733333, 0.376     , 0.55466667]), 'predict_other': array([0.        , 0.        , 0.38666667]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 1.6484448708593846
# g loss: 3.6606735959649086
# Test acc: {'query_nway': array([0.2       , 0.22666667, 0.58666667]), 'predict_other': array([0.        , 0.        , 0.37333333]), 'gen_discrim': array([0., 1., 1.])}
# step 15700
# d loss: 1.7596431970596313
# g loss: 2.3024559020996094
# accs {'query_nway': array([0.20266667, 0.27733333, 0.392     ]), 'predict_other': array([0.        , 0.        , 0.00266667]), 'gen_discrim': array([0.   , 0.872, 0.872])}
# step 15800
# d loss: 1.7739359140396118
# g loss: 3.673823595046997
# accs {'query_nway': array([0.2       , 0.33866667, 0.416     ]), 'predict_other': array([0.        , 0.        , 0.31733333]), 'gen_discrim': array([0., 1., 1.])}
# step 15900
# d loss: 1.6282341480255127
# g loss: 2.7634220123291016
# accs {'query_nway': array([0.2  , 0.368, 0.504]), 'predict_other': array([0.   , 0.   , 0.216]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.718532960116863
# g loss: 2.592350311949849
# Test acc: {'query_nway': array([0.17333333, 0.34666667, 0.57333333]), 'predict_other': array([0.        , 0.        , 0.97333333]), 'gen_discrim': array([0., 1., 1.])}
# step 16000
# d loss: 1.289512276649475
# g loss: 3.5827691555023193
# accs {'query_nway': array([0.2       , 0.37333333, 0.55466667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0.   , 0.976, 0.976])}
# step 16100
# d loss: 1.8899328708648682
# g loss: 3.4659626483917236
# accs {'query_nway': array([0.20266667, 0.46933333, 0.48266667]), 'predict_other': array([0.        , 0.        , 0.37333333]), 'gen_discrim': array([0., 1., 1.])}
# step 16200
# d loss: 1.7130529880523682
# g loss: 1.941158652305603
# accs {'query_nway': array([0.20266667, 0.30666667, 0.46933333]), 'predict_other': array([0.  , 0.  , 0.04]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# d loss: 3.0480092011392115
# ...
# step 38500
# d loss: 1.4992014169692993
# g loss: 3.6756227016448975
# accs {'query_nway': array([0.2       , 0.49066667, 0.59466667]), 'predict_other': array([0.        , 0.        , 0.17333333]), 'gen_discrim': array([0., 1., 1.])}
# step 38600
# d loss: 1.3579908609390259
# g loss: 4.956833839416504
# accs {'query_nway': array([0.2       , 0.37066667, 0.504     ]), 'predict_other': array([0.        , 0.        , 0.03733333]), 'gen_discrim': array([0., 1., 1.])}
# step 38700
# d loss: 1.0122063159942627
# g loss: 3.7179856300354004
# accs {'query_nway': array([0.2       , 0.50133333, 0.68533333]), 'predict_other': array([0.        , 0.        , 0.02933333]), 'gen_discrim': array([0.   , 0.952, 0.952])}
# d loss: 2.875918456166983
# g loss: 4.251131622493267
# Test acc: {'query_nway': array([0.2       , 0.62666667, 0.78666667]), 'predict_other': array([0.        , 0.        , 0.02666667]), 'gen_discrim': array([0., 1., 1.])}
# step 38800
# d loss: 1.3800413608551025
# g loss: 3.7592580318450928
# accs {'query_nway': array([0.2       , 0.49066667, 0.56      ]), 'predict_other': array([0.        , 0.        , 0.13333333]), 'gen_discrim': array([0.   , 0.976, 0.976])}
# step 38900
# d loss: 1.6523422002792358
# g loss: 4.130342960357666
# accs {'query_nway': array([0.2       , 0.34133333, 0.408     ]), 'predict_other': array([0.   , 0.   , 0.064]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 39000
# d loss: 1.408206820487976
# g loss: 5.28062105178833
# accs {'query_nway': array([0.2       , 0.392     , 0.50133333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 1.4694131642580033
# g loss: 5.481577277183533
# Test acc: {'query_nway': array([0.2       , 0.64      , 0.78666667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 39100
# d loss: 1.4721288681030273
# g loss: 5.2662858963012695
# accs {'query_nway': array([0.2  , 0.576, 0.6  ]), 'predict_other': array([0.        , 0.        , 0.22666667]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 39200
# d loss: 1.2760289907455444
# g loss: 5.260034084320068
# accs {'query_nway': array([0.2       , 0.45066667, 0.48266667]), 'predict_other': array([0.        , 0.        , 0.02666667]), 'gen_discrim': array([0., 1., 1.])}
# step 39300
# d loss: 1.5430282354354858
# g loss: 4.23745584487915
# accs {'query_nway': array([0.2       , 0.37066667, 0.47466667]), 'predict_other': array([0.        , 0.        , 0.21066667]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# d loss: 3.0198554381728173
# g loss: 3.634828592091799
# Test acc: {'query_nway': array([0.2       , 0.49333333, 0.53333333]), 'predict_other': array([0.        , 0.        , 0.98666667]), 'gen_discrim': array([0., 1., 1.])}
# step 39400
# d loss: 1.1258805990219116
# g loss: 4.176637172698975
# accs {'query_nway': array([0.2       , 0.48266667, 0.66933333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 39500
# d loss: 1.5355358123779297
# g loss: 3.8467507362365723
# accs {'query_nway': array([0.2       , 0.552     , 0.67733333]), 'predict_other': array([0.   , 0.   , 0.176]), 'gen_discrim': array([0., 1., 1.])}
# step 39600
# d loss: 1.094760775566101
# g loss: 3.5839736461639404
# accs {'query_nway': array([0.2       , 0.54666667, 0.68266667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0.   , 0.976, 0.976])}
# d loss: 2.9847125142812727
# g loss: 3.596144436299801
# Test acc: {'query_nway': array([0.2       , 0.4       , 0.58666667]), 'predict_other': array([0.  , 0.  , 0.04]), 'gen_discrim': array([0.  , 0.96, 0.96])}
# step 39700
# d loss: 1.5338934659957886
# g loss: 3.7366135120391846
# accs {'query_nway': array([0.2       , 0.36266667, 0.528     ]), 'predict_other': array([0.        , 0.        , 0.09333333]), 'gen_discrim': array([0.   , 0.976, 0.976])}
# step 39800
# d loss: 1.3474229574203491
# g loss: 4.719546794891357
# accs {'query_nway': array([0.2       , 0.46666667, 0.528     ]), 'predict_other': array([0.        , 0.        , 0.05333333]), 'gen_discrim': array([0.   , 0.976, 0.976])}
# step 39900
# d loss: 1.535804271697998
# g loss: 2.693589448928833
# accs {'query_nway': array([0.2       , 0.40266667, 0.44533333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 3.735710306465626
# g loss: 5.144406570494175
# Test acc: {'query_nway': array([0.2       , 0.52      , 0.58666667]), 'predict_other': array([0.  , 0.  , 0.92]), 'gen_discrim': array([0., 1., 1.])}
# step 40000
# d loss: 1.1891921758651733
# g loss: 3.8827970027923584
# accs {'query_nway': array([0.2       , 0.53333333, 0.66666667]), 'predict_other': array([0.  , 0.  , 0.08]), 'gen_discrim': array([0.   , 0.944, 0.944])}
# step 40100
# d loss: 1.4463257789611816
# g loss: 5.413499355316162
# accs {'query_nway': array([0.2       , 0.448     , 0.54933333]), 'predict_other': array([0.        , 0.        , 0.24533333]), 'gen_discrim': array([0., 1., 1.])}
# step 40200
# d loss: 1.3830589056015015
# g loss: 4.007318496704102
# accs {'query_nway': array([0.2       , 0.41333333, 0.59466667]), 'predict_other': array([0.   , 0.   , 0.104]), 'gen_discrim': array([0.   , 0.968, 0.968])}
# d loss: 2.695125391334295
# g loss: 3.488580921292305
# Test acc: {'query_nway': array([0.2       , 0.96      , 0.90666667]), 'predict_other': array([0.        , 0.        , 0.74666667]), 'gen_discrim': array([0.  , 0.92, 0.92])}
# step 40300
# d loss: 0.8964048624038696
# g loss: 5.598266124725342
# accs {'query_nway': array([0.2       , 0.56266667, 0.68533333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 40400
# d loss: 1.1981605291366577
# g loss: 7.197726726531982
# accs {'query_nway': array([0.2  , 0.472, 0.584]), 'predict_other': array([0.  , 0.  , 0.08]), 'gen_discrim': array([0., 1., 1.])}
# step 40500
# d loss: 1.1387948989868164
# g loss: 6.140473365783691
# accs {'query_nway': array([0.19733333, 0.44      , 0.54133333]), 'predict_other': array([0.        , 0.        , 0.01333333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 1.6091545298695564
# g loss: 5.93887737095356
# Test acc: {'query_nway': array([0.2       , 0.54666667, 0.78666667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 40600
# d loss: 1.3432574272155762
# g loss: 6.307882308959961
# accs {'query_nway': array([0.2       , 0.42666667, 0.536     ]), 'predict_other': array([0.   , 0.   , 0.128]), 'gen_discrim': array([0., 1., 1.])}
# step 40700
# d loss: 1.4753082990646362
# g loss: 5.079823970794678
# accs {'query_nway': array([0.2  , 0.288, 0.4  ]), 'predict_other': array([0.        , 0.        , 0.01333333]), 'gen_discrim': array([0., 1., 1.])}
# step 40800
# d loss: 3.5047805309295654
# g loss: 7.0631537437438965
# accs {'query_nway': array([0.2       , 0.448     , 0.48533333]), 'predict_other': array([0.        , 0.        , 0.41866667]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.3183758072555065
# g loss: 1.7232263768091798
# Test acc: {'query_nway': array([0.2       , 0.58666667, 0.77333333]), 'predict_other': array([0.        , 0.        , 0.02666667]), 'gen_discrim': array([0.  , 0.04, 0.04])}
# step 40900
# d loss: 1.018831491470337
# g loss: 6.066127300262451
# accs {'query_nway': array([0.2       , 0.43466667, 0.62933333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 41000
# d loss: 1.7016788721084595
# g loss: 1.9084542989730835
# accs {'query_nway': array([0.2       , 0.45866667, 0.56      ]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0.   , 0.848, 0.848])}
# step 41100
# d loss: 1.4813299179077148
# g loss: 5.4003071784973145
# accs {'query_nway': array([0.2       , 0.44533333, 0.54133333]), 'predict_other': array([0.        , 0.        , 0.18666667]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# d loss: 3.1184426471590996
# g loss: 3.897469478845596
# Test acc: {'query_nway': array([0.2       , 0.42666667, 0.6       ]), 'predict_other': array([0.        , 0.        , 0.77333333]), 'gen_discrim': array([0., 1., 1.])}
# step 41200
# d loss: 1.3674718141555786
# g loss: 3.4877209663391113
# accs {'query_nway': array([0.2       , 0.44533333, 0.54666667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 41300
# d loss: 1.2016597986221313
# g loss: 4.450263500213623
# accs {'query_nway': array([0.2       , 0.37866667, 0.56266667]), 'predict_other': array([0.        , 0.        , 0.01066667]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# step 41400
# d loss: 2.1908981800079346
# g loss: 5.523532390594482
# accs {'query_nway': array([0.2       , 0.39733333, 0.4       ]), 'predict_other': array([0.        , 0.        , 0.18933333]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.3264923304319383
# g loss: 2.900624557584524
# Test acc: {'query_nway': array([0.2       , 0.38666667, 0.61333333]), 'predict_other': array([0.        , 0.        , 0.94666667]), 'gen_discrim': array([0., 1., 1.])}
# step 41500
# d loss: 1.39594304561615
# g loss: 2.835728883743286
# accs {'query_nway': array([0.2       , 0.44533333, 0.51466667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0.  , 0.92, 0.92])}
# step 41600
# d loss: 1.2880524396896362
# g loss: 5.697929382324219
# accs {'query_nway': array([0.2       , 0.50133333, 0.53066667]), 'predict_other': array([0.   , 0.   , 0.008]), 'gen_discrim': array([0., 1., 1.])}
# step 41700
# d loss: 1.3301557302474976
# g loss: 5.293296813964844
# accs {'query_nway': array([0.2  , 0.432, 0.488]), 'predict_other': array([0.        , 0.        , 0.00266667]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# d loss: 2.9041797965765
# g loss: 4.831834697723389
# Test acc: {'query_nway': array([0.2       , 0.49333333, 0.56      ]), 'predict_other': array([0.  , 0.  , 0.92]), 'gen_discrim': array([0., 1., 1.])}
# step 41800
# d loss: 0.8982418179512024
# g loss: 7.444046974182129
# accs {'query_nway': array([0.2       , 0.57333333, 0.70666667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 41900
# d loss: 1.9381130933761597
# g loss: 5.877713680267334
# accs {'query_nway': array([0.2       , 0.40533333, 0.52533333]), 'predict_other': array([0.        , 0.        , 0.24533333]), 'gen_discrim': array([0., 1., 1.])}
# step 42000
# d loss: 1.182309627532959
# g loss: 3.4153599739074707
# accs {'query_nway': array([0.2       , 0.54666667, 0.656     ]), 'predict_other': array([0.        , 0.        , 0.10666667]), 'gen_discrim': array([0.   , 0.952, 0.952])}
# d loss: 3.0601145781576635
# g loss: 4.261234694346785
# Test acc: {'query_nway': array([0.2       , 0.30666667, 0.56      ]), 'predict_other': array([0.  , 0.  , 0.96]), 'gen_discrim': array([0., 1., 1.])}
# step 42100
# d loss: 1.3589156866073608
# g loss: 4.444555759429932
# accs {'query_nway': array([0.2       , 0.42133333, 0.45333333]), 'predict_other': array([0.        , 0.        , 0.01066667]), 'gen_discrim': array([0., 1., 1.])}
# step 42200
# d loss: 1.6041603088378906
# g loss: 4.223557949066162
# accs {'query_nway': array([0.2       , 0.33333333, 0.33866667]), 'predict_other': array([0.        , 0.        , 0.00266667]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 42300
# d loss: 1.3127385377883911
# g loss: 5.389476299285889
# accs {'query_nway': array([0.2       , 0.39733333, 0.44533333]), 'predict_other': array([0.        , 0.        , 0.00266667]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# d loss: 1.5470197536051273
# g loss: 4.970584389567375
# Test acc: {'query_nway': array([0.2       , 0.36      , 0.57333333]), 'predict_other': array([0.        , 0.        , 0.09333333]), 'gen_discrim': array([0., 1., 1.])}
# step 42400
# d loss: 1.2372292280197144
# g loss: 9.42277717590332
# accs {'query_nway': array([0.2       , 0.38133333, 0.54933333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 42500
# d loss: 0.7214536070823669
# g loss: 7.773679256439209
# accs {'query_nway': array([0.2       , 0.624     , 0.75733333]), 'predict_other': array([0.   , 0.   , 0.008]), 'gen_discrim': array([0., 1., 1.])}
# step 42600
# d loss: 1.0889984369277954
# g loss: 5.465156555175781
# accs {'query_nway': array([0.2       , 0.57066667, 0.624     ]), 'predict_other': array([0.   , 0.   , 0.016]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.2837315544486048
# g loss: 6.800502574443817
# Test acc: {'query_nway': array([0.2       , 0.26666667, 0.4       ]), 'predict_other': array([0.        , 0.        , 0.97333333]), 'gen_discrim': array([0., 1., 1.])}
# step 42700
# d loss: 1.6943186521530151
# g loss: 5.755989074707031
# accs {'query_nway': array([0.2       , 0.38666667, 0.41333333]), 'predict_other': array([0.        , 0.        , 0.15733333]), 'gen_discrim': array([0., 1., 1.])}
# step 42800
# d loss: 1.5349539518356323
# g loss: 5.209414005279541
# accs {'query_nway': array([0.2       , 0.35466667, 0.38666667]), 'predict_other': array([0.        , 0.        , 0.00266667]), 'gen_discrim': array([0.   , 0.968, 0.968])}
# step 42900
# d loss: 1.4351061582565308
# g loss: 7.6764421463012695
# accs {'query_nway': array([0.2       , 0.464     , 0.60533333]), 'predict_other': array([0.   , 0.   , 0.224]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 1.7468580842018127
# g loss: 3.360979675501585
# Test acc: {'query_nway': array([0.2       , 0.45333333, 0.68      ]), 'predict_other': array([0.        , 0.        , 0.33333333]), 'gen_discrim': array([0., 1., 1.])}
# step 43000
# d loss: 1.2751888036727905
# g loss: 4.557366371154785
# accs {'query_nway': array([0.2  , 0.448, 0.536]), 'predict_other': array([0.   , 0.   , 0.072]), 'gen_discrim': array([0., 1., 1.])}
# step 43100
# d loss: 0.9205469489097595
# g loss: 5.64253568649292
# accs {'query_nway': array([0.2       , 0.57866667, 0.712     ]), 'predict_other': array([0.   , 0.   , 0.048]), 'gen_discrim': array([0., 1., 1.])}
# step 43200
# d loss: 1.375017523765564
# g loss: 7.350701332092285
# accs {'query_nway': array([0.2       , 0.43466667, 0.49066667]), 'predict_other': array([0.        , 0.        , 0.01866667]), 'gen_discrim': array([0., 1., 1.])}
# d loss: 2.523951606452465
# g loss: 6.299478346109391
# Test acc: {'query_nway': array([0.2 , 0.24, 0.48]), 'predict_other': array([0.        , 0.        , 0.85333333]), 'gen_discrim': array([0., 1., 1.])}
# step 43300
# d loss: 1.0141959190368652
# g loss: 5.269492149353027
# accs {'query_nway': array([0.2       , 0.50933333, 0.68      ]), 'predict_other': array([0.   , 0.   , 0.112]), 'gen_discrim': array([0., 1., 1.])}
# step 43400
# d loss: 1.0513885021209717
# g loss: 5.796137809753418
# accs {'query_nway': array([0.2       , 0.44533333, 0.61333333]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 43500
# d loss: 1.1044120788574219
# g loss: 6.281807899475098
# accs {'query_nway': array([0.2       , 0.46666667, 0.57866667]), 'predict_other': array([0.        , 0.        , 0.05333333]), 'gen_discrim': array([0.   , 0.984, 0.984])}
# d loss: 1.729296012967825
# g loss: 6.046509825438261
# Test acc: {'query_nway': array([0.2       , 0.70666667, 0.82666667]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 43600
# d loss: 0.7127772569656372
# g loss: 7.135945796966553
# accs {'query_nway': array([0.2  , 0.6  , 0.768]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0., 1., 1.])}
# step 43700
# d loss: 1.1765081882476807
# g loss: 5.732375621795654
# accs {'query_nway': array([0.2  , 0.416, 0.568]), 'predict_other': array([0., 0., 0.]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# step 43800
# d loss: 1.177390694618225
# g loss: 5.939061641693115
# accs {'query_nway': array([0.2       , 0.46666667, 0.536     ]), 'predict_other': array([0.        , 0.        , 0.00266667]), 'gen_discrim': array([0.   , 0.992, 0.992])}
# d loss: 2.0026471234858034
# g loss: 6.244051593542099
# Test acc: {'query_nway': array([0.2       , 0.41333333, 0.42666667]), 'predict_other': array([0.        , 0.        , 0.14666667]), 'gen_discrim': array([0., 1., 1.])}
# step 43900
# d loss: 1.2730884552001953
# g loss: 9.167323112487793
# accs {'query_nway': array([0.2       , 0.45333333, 0.576     ]), 'predict_other': array([0.        , 0.        , 0.12533333]), 'gen_discrim': array([0., 1., 1.])}

# %%
tmp_x_spt.size()

# %%
tmp_y_spt.size()

# %%
tmp_x_qry.size()

# %%
tmp_y_qry.size()

# %%
tmp_y_qry
