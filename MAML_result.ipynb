# %%
import  torch, os
import  numpy as np
import  scipy.stats
from    torch.utils.data import DataLoader
from    torch.optim import lr_scheduler
import  random, sys, pickle
from utils.results.dataloaders import train_data_gen , test_data_gen
# from maml_meta import Meta
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter
from    torch import optim
from maml_learner import Learner
from    torch.nn import functional as F
from    copy import deepcopy

import json
import shutil
import torchvision.utils as vutils

# %%
with open("results_configs/5shot4distractor15_with_data_augmentation_test_guasian_noise_without_cosine.json") as json_file:
    args = json.load(json_file)
print(args)
# if os.path.exists("maml_runs/" + args["save_path"]):
#     shutil.rmtree("maml_runs/" + args["save_path"])
writer = SummaryWriter("results_runs/" + args["save_path"])
# Out:
# {'epoch': 60000, 'n_way': 5, 'k_spt': 5, 'k_qry': 10, 'data_augmentation_num': 5, 'img_sz': 84, 'task_num': 5, 'img_c': 3, 'meta_lr': 0.001, 'update_lr': 0.01, 'update_step': 5, 'update_step_test': 10, 'loss': 'cross_entropy', 'number_of_training_steps_per_iter': 5, 'multi_step_loss_num_epochs': 10, 'spy_gan_num': 1, 'qry_gan_num': 5, 'num_distractor': 4, 'gan': 0, 'spy_distractor_num': 1, 'qry_distractor_num': 15, 'batch_for_gradient': 25, 'fm': 32, 'no_save': 0, 'learn_inner_lr': 0, 'create_graph': 0, 'msl': 1, 'single_fast_test': 0, 'consine_schedule': 0, 'eta_min': 0.0001, 'save_path': '5shot4distractor15_with_data_augmentation_test_guasian_noise_without_cosine'}

# %%
def mkdir_p(path):
    if not os.path.exists("model_results/" + path):
        os.makedirs("model_results/" + path)

# %%
# BASE
fm = args["fm"]
config = [
    ("conv2d", [fm, 3, 3, 3, 1, 0]),
    ("leakyrelu", [0.2,True]),
    ("bn", [fm]),
    ("max_pool2d", [2, 2, 0]),
    ("conv2d", [fm, fm, 3, 3, 1, 0]),
    ("leakyrelu", [0.2,True]),
    ("bn", [fm]),
    ("max_pool2d", [2, 2, 0]),
    ("conv2d", [fm, fm, 3, 3, 1, 0]),
    ("leakyrelu", [0.2,True]),
    ("bn", [fm]),
    ("max_pool2d", [2, 2, 0]),
    ("conv2d", [fm, fm, 3, 3, 1, 0]),
    ("leakyrelu", [0.2,True]),
    ("bn", [fm]),
    ("max_pool2d", [2, 1, 0]),
    ("flatten", []),
    ("linear", [6, fm * 5 * 5])
]

# %%
train_data_generator = train_data_gen(args)
test_data_generator = test_data_gen(args)
# Out:
# load datasets/BelgiumTSC
# load complete time 0.5205512046813965
# load datasets/ArTS
# load complete time 0.5057330131530762
# load datasets/chinese_traffic_sign
# load complete time 0.9899024963378906
# load datasets/CVL
# load complete time 0.66534423828125
# load datasets/FullJCNN2013
# load complete time 0.33189988136291504
# load datasets/logo_2k
# load complete time 1.1042015552520752
# load datasets/GTSRB
# load complete time 0.09869790077209473
# load datasets/DFG
# load complete time 0.03539252281188965

# %%
class Meta(nn.Module):
    """
    Meta Learner
    """
    def __init__(self, args, config):
        """

        :param args:
        """
        super(Meta, self).__init__()

        self.update_lr = args["update_lr"]
        self.meta_lr = args["meta_lr"]
        self.n_way = args["n_way"]
        self.k_spt = args["k_spt"]
        self.k_qry = args["k_qry"]
        self.task_num = args["task_num"]
        self.update_step = args["update_step"]
        self.update_step_test = args["update_step_test"]
        self.distractor = args["num_distractor"]
        self.net = Learner(config, args["img_c"], args["img_sz"])
        self.meta_optim = optim.Adam(self.net.parameters(), lr=self.meta_lr)
        if args["consine_schedule"]:
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(self.meta_optim, T_max=args["consine_schedule"], eta_min=args["eta_min"])
        self.device = torch.device("cuda")
        self.gan = args["gan"]
        self.multi_step_loss_num_epochs = args["multi_step_loss_num_epochs"]
        self.msl = args["msl"]
    def get_per_step_loss_importance_vector(self):

        loss_weights = np.ones(shape=(self.update_step)) * (
                1.0 / self.update_step)
        decay_rate = 1.0 / self.update_step / self.multi_step_loss_num_epochs
        min_value_for_non_final_losses = 0.03 / self.update_step
        for i in range(len(loss_weights) - 1):
            curr_value = np.maximum(loss_weights[i] - (self.current_epoch * decay_rate), min_value_for_non_final_losses)
            loss_weights[i] = curr_value

        curr_value = np.minimum(
            loss_weights[-1] + (self.current_epoch * (self.update_step - 1) * decay_rate),
            1.0 - ((self.update_step - 1) * min_value_for_non_final_losses))
        loss_weights[-1] = curr_value
        loss_weights = torch.Tensor(loss_weights).to(device=self.device)
        return loss_weights

    def forward(self, x_spt, y_spt, x_qry, y_qry, current_epoch,unlabel_spt_image=None, unlabel_qry_image=None,gan_spt=None, gan_qry=None):
        """

        :param x_spt:   [b, setsz, c_, h, w]
        :param y_spt:   [b, setsz]
        :param x_qry:   [b, querysz, c_, h, w]
        :param y_qry:   [b, querysz]
        :return:
        """
        self.current_epoch = current_epoch
        per_step_loss_importance_vectors = self.get_per_step_loss_importance_vector()
        task_num, setsz, c_, h, w = x_spt.size()
        querysz = x_qry.size(1)
        if self.gan :
            gan_sptsz = gan_spt.size(1)
            gan_qrysz = gan_qry.size(1)
        else:
            gan_sptsz = 0
            gan_qrysz = 0
        if self.distractor or self.gan:
            corrects = {}
            corrects["total_query_nway"] = np.zeros(self.update_step + 1)
            if self.distractor:
                unlabel_querysz = unlabel_qry.size(1)
                corrects["query_nway_recall"] = np.zeros(self.update_step + 1)
                corrects["label_query_nway_recall"] = np.zeros(self.update_step + 1)
                corrects["distractor_query_nway_recall"] = np.zeros(self.update_step + 1)
            if self.gan :
                corrects["gan_query_nway"] = np.zeros(self.update_step + 1)
        else:
            corrects = {key: np.zeros(self.update_step + 1) for key in 
                [
                "query_nway_recall",
                "label_query_nway_recall"
                ]}
        losses_q = [0 for _ in range(self.update_step + 1)]  # losses_q[i] is the loss on step i

        for i in range(task_num):
            spt_image = x_spt[i]
            spt_label = y_spt[i]
            qry_image = x_qry[i]
            qry_label = y_qry[i]
            if self.distractor:
                spt_image = torch.concat((spt_image,unlabel_spt[i]))
                spt_unlabel_label = torch.full((unlabel_spt.size(1),), 5, dtype=torch.long,device=self.device)
                spt_label = torch.cat((spt_label,spt_unlabel_label))
                qry_image = torch.concat((qry_image,unlabel_qry[i]))
                qry_unlabel_label = torch.full((unlabel_qry.size(1),), 5, dtype=torch.long,device=self.device)
                qry_label = torch.cat((qry_label,qry_unlabel_label))
            if self.gan :
                spt_image = torch.concat((spt_image,gan_spt[i]))
                spt_gan_label = torch.full((gan_spt.size(1),), 5, dtype=torch.long,device=self.device)
                spt_label = torch.cat((spt_label,spt_gan_label))
                qry_image = torch.concat((qry_image,gan_qry[i]))
                qry_gan_label = torch.full((gan_qry.size(1),), 5, dtype=torch.long,device=self.device)
                qry_label = torch.cat((qry_label,qry_gan_label))

            # 1. run the i-th task and compute loss for k=0
            logits = self.net(spt_image, vars=None, bn_training=True)
            loss = F.cross_entropy(logits, spt_label)
            grad = torch.autograd.grad(loss, self.net.parameters())
            fast_weights = list(map(lambda p: p[1] - self.update_lr * p[0], zip(grad, self.net.parameters())))

            # this is the loss and accuracy before first update
            with torch.no_grad():
                # [setsz, nway]
                if self.distractor or self.gan:
                    total_logits_q = self.net(qry_image, self.net.parameters(), bn_training=False)
                    total_pred_q = F.softmax(total_logits_q, dim=1).argmax(dim=1)
                    total_q_correct = torch.eq(total_pred_q, qry_label).sum().item()
                    corrects["total_query_nway"][0] += total_q_correct
                    loss_q = F.cross_entropy(total_logits_q, qry_label)
                    losses_q[0] += loss_q
                    if self.distractor:
                        label_logits_q = self.net(x_qry[i], self.net.parameters(), bn_training=False)
                        label_pred_q = F.softmax(label_logits_q, dim=1).argmax(dim=1)
                        label_pred_q_correct = torch.eq(label_pred_q, y_qry[i]).sum().item()
                        corrects["label_query_nway_recall"][0] += label_pred_q_correct
                        label_pred_q = F.softmax(label_logits_q[:,:-1], dim=1).argmax(dim=1)
                        label_pred_q_correct = torch.eq(label_pred_q, y_qry[i]).sum().item()
                        corrects["query_nway_recall"][0] += label_pred_q_correct
                        

                        unlabel_logits_q = self.net(unlabel_qry[i], self.net.parameters(), bn_training=False)
                        unlabel_pred_q = F.softmax(unlabel_logits_q, dim=1).argmax(dim=1)
                        other = torch.eq(unlabel_pred_q, qry_unlabel_label).sum().item()
                        corrects["distractor_query_nway_recall"][0] += other
                    if self.gan :
                        gan_logits_q = self.net(gan_qry[i], self.net.parameters(), bn_training=False)
                        gan_pred_q = F.softmax(gan_logits_q, dim=1).argmax(dim=1)
                        gan_counts = torch.eq(gan_pred_q, qry_gan_label).sum().item()
                        corrects["gan_query_nway"][0] += gan_counts
                else:
                    logits_q = self.net(qry_image, self.net.parameters(), bn_training=True)
                    loss_q = F.cross_entropy(logits_q, qry_label)
                    pred_q = F.softmax(logits_q[:,:-1], dim=1).argmax(dim=1)
                    q_discrim_correct = torch.eq(pred_q, qry_label).sum().item()
                    corrects["query_nway_recall"][0] += q_discrim_correct
                    pred_q = F.softmax(logits_q, dim=1).argmax(dim=1)
                    q_discrim_correct = torch.eq(pred_q, qry_label).sum().item()
                    corrects["label_query_nway_recall"][0] += q_discrim_correct
                    losses_q[0] += loss_q
            # this is the loss and accuracy after the first update
            with torch.no_grad():
                # [setsz, nway]
                if self.distractor or self.gan:
                    
                    total_logits_q = self.net(qry_image,fast_weights , bn_training=False)
                    total_pred_q = F.softmax(total_logits_q, dim=1).argmax(dim=1)
                    total_q_correct = torch.eq(total_pred_q, qry_label).sum().item()
                    corrects["total_query_nway"][1] += total_q_correct
                    loss_q = F.cross_entropy(total_logits_q, qry_label)
                    losses_q[1] += loss_q
                    if self.distractor:
                        label_logits_q = self.net(x_qry[i], fast_weights, bn_training=False)
                        label_pred_q = F.softmax(label_logits_q, dim=1).argmax(dim=1)
                        label_pred_q_correct = torch.eq(label_pred_q, y_qry[i]).sum().item()
                        corrects["label_query_nway_recall"][1] += label_pred_q_correct
                        label_pred_q = F.softmax(label_logits_q[:,:-1], dim=1).argmax(dim=1)
                        label_pred_q_correct = torch.eq(label_pred_q, y_qry[i]).sum().item()
                        corrects["query_nway_recall"][1] += label_pred_q_correct
                        
                        unlabel_logits_q = self.net(unlabel_qry[i], fast_weights, bn_training=False)
                        unlabel_pred_q = F.softmax(unlabel_logits_q, dim=1).argmax(dim=1)
                        other = torch.eq(unlabel_pred_q, qry_unlabel_label).sum().item()
                        corrects["distractor_query_nway_recall"][1] += other
                    if self.gan :
                        gan_logits_q = self.net(gan_qry[i], fast_weights, bn_training=False)
                        gan_pred_q = F.softmax(gan_logits_q, dim=1).argmax(dim=1)
                        gan_counts = torch.eq(gan_pred_q, qry_gan_label).sum().item()
                        corrects["gan_query_nway"][1] += gan_counts
                else:
                    logits_q = self.net(qry_image, fast_weights, bn_training=False)
                    loss_q = F.cross_entropy(logits_q, qry_label)
                    pred_q = F.softmax(logits_q, dim=1).argmax(dim=1)
                    q_discrim_correct = torch.eq(pred_q, qry_label).sum().item()
                    corrects["query_nway_recall"][1] += q_discrim_correct
                    pred_q = F.softmax(logits_q[:,:-1], dim=1).argmax(dim=1)
                    q_discrim_correct = torch.eq(pred_q, qry_label).sum().item()
                    corrects["label_query_nway_recall"][1] += q_discrim_correct
                    losses_q[1] += loss_q

            for k in range(1, self.update_step):
                # 1. run the i-th task and compute loss for k=1~K-1
                logits = self.net(spt_image, fast_weights, bn_training=True)
                loss = F.cross_entropy(logits, spt_label)
                # 2. compute grad on theta_pi
                grad = torch.autograd.grad(loss, fast_weights)
                # 3. theta_pi = theta_pi - train_lr * grad
                fast_weights = list(map(lambda p: p[1] - self.update_lr * p[0], zip(grad, fast_weights)))

                logits_q = self.net(qry_image, fast_weights, bn_training=True)
                # loss_q will be overwritten and just keep the loss_q on last update step.
                loss_q = F.cross_entropy(logits_q, qry_label)
                losses_q[k + 1] += loss_q
                with torch.no_grad():
                    if self.distractor or self.gan:
                        total_logits_q = self.net(qry_image, fast_weights, bn_training=False)
                        total_pred_q = F.softmax(total_logits_q, dim=1).argmax(dim=1)
                        total_q_correct = torch.eq(total_pred_q, qry_label).sum().item()
                        corrects["total_query_nway"][k+1] += total_q_correct
                        if self.distractor:
                            label_logits_q = self.net(x_qry[i], fast_weights, bn_training=False)
                            label_pred_q = F.softmax(label_logits_q, dim=1).argmax(dim=1)
                            label_pred_q_correct = torch.eq(label_pred_q, y_qry[i]).sum().item()
                            corrects["label_query_nway_recall"][k+1] += label_pred_q_correct
                            label_pred_q = F.softmax(label_logits_q[:,:-1], dim=1).argmax(dim=1)
                            label_pred_q_correct = torch.eq(label_pred_q, y_qry[i]).sum().item()
                            corrects["query_nway_recall"][k+1] += label_pred_q_correct
                            
                            unlabel_logits_q = self.net(unlabel_qry[i], fast_weights, bn_training=False)
                            unlabel_pred_q = F.softmax(unlabel_logits_q, dim=1).argmax(dim=1)
                            other = torch.eq(unlabel_pred_q, qry_unlabel_label).sum().item()
                            corrects["distractor_query_nway_recall"][k+1] += other
                        if self.gan :
                            gan_logits_q = self.net(gan_qry[i], fast_weights, bn_training=False)
                            gan_pred_q = F.softmax(gan_logits_q, dim=1).argmax(dim=1)
                            gan_counts = torch.eq(gan_pred_q, qry_gan_label).sum().item()
                            corrects["gan_query_nway"][k+1] += gan_counts
                    else:
                        pred_q = F.softmax(logits_q, dim=1).argmax(dim=1)
                        q_discrim_correct = torch.eq(pred_q, qry_label).sum().item()
                        corrects["query_nway_recall"][k+1] += q_discrim_correct
                        pred_q = F.softmax(logits_q[:,:-1], dim=1).argmax(dim=1)
                        q_discrim_correct = torch.eq(pred_q, qry_label).sum().item()
                        corrects["label_query_nway_recall"][k+1] += q_discrim_correct
        # end of all tasks
        # sum over all losses on query set across all tasks
        loss_q = 0
        if self.msl:
            for num_step, loss in enumerate(losses_q[1:]):
                loss_q = loss_q + per_step_loss_importance_vectors[num_step] * loss / task_num
        else:
            loss_q = losses_q[-1]
        # optimize theta parameters
        self.meta_optim.zero_grad()
        loss_q.backward()

        self.meta_optim.step()
        
        accs = {}
        if (self.distractor or self.gan):
            accs["total_query_nway"] = corrects["total_query_nway"] / (task_num * (querysz + unlabel_querysz + gan_qrysz))
            if self.distractor:
                accs["label_query_nway_recall"] = corrects["label_query_nway_recall"] / (task_num * querysz)
                accs["query_nway_recall"] = corrects["query_nway_recall"] / (task_num * querysz)
                accs["distractor_query_nway_recall"] = corrects["distractor_query_nway_recall"] / (task_num * unlabel_querysz)
            if gan_qrysz:
                accs["gan_query_nway"] = corrects["gan_query_nway"] / (task_num * gan_qrysz)
        else:
            accs["query_nway_recall"] = corrects["query_nway_recall"] / (task_num * querysz)
            accs["label_query_nway_recall"] = corrects["label_query_nway_recall"] / (task_num * querysz)
        return accs,loss_q


    def finetunning(self, x_spt, y_spt, x_qry, y_qry, unlabel_spt=None, unlabel_qry=None, gan_spt=None, gan_qry=None):

        assert len(x_spt.shape) == 4
        querysz = x_qry.size(0)

        corrects = {}
        corrects["total_query_nway"] = np.zeros(self.update_step_test + 1)

        unlabel_querysz = unlabel_qry.size(0)

        corrects["query_nway_recall"] = np.zeros(self.update_step_test + 1)
        corrects["distractor_query_nway_recall"] = np.zeros(self.update_step_test + 1)

        # in order to not ruin the state of running_mean/variance and bn_weight/bias
        # we finetunning on the copied model instead of self.net
        net = deepcopy(self.net)
        spt_image = x_spt
        spt_label = y_spt
        qry_image = x_qry
        qry_label = y_qry
        if self.distractor:
            spt_image = torch.concat((spt_image,unlabel_spt))
            spt_unlabel_label = torch.full((unlabel_spt.size(0),), 5, dtype=torch.long,device=self.device)
            spt_label = torch.cat((spt_label,spt_unlabel_label))

        qry_image = torch.concat((qry_image,unlabel_qry))
        qry_unlabel_label = torch.full((unlabel_qry.size(0),), 5, dtype=torch.long,device=self.device)
        qry_label = torch.cat((qry_label,qry_unlabel_label))

        # 1. run the i-th task and compute loss for k=0
        logits = net(spt_image)
        loss = F.cross_entropy(logits, spt_label)

        grad = torch.autograd.grad(loss, net.parameters())
        fast_weights = list(map(lambda p: p[1] - self.update_lr * p[0], zip(grad, net.parameters())))

        # this is the loss and accuracy before first update
        with torch.no_grad():

            total_logits_q = self.net(qry_image,self.net.parameters() , bn_training=False)
            total_pred_q = F.softmax(total_logits_q, dim=1).argmax(dim=1)
            total_q_correct = torch.eq(total_pred_q, qry_label).sum().item()
            corrects["total_query_nway"][1] += total_q_correct
            loss_q = F.cross_entropy(total_logits_q, qry_label)

            label_logits_q = self.net(x_qry, self.net.parameters(), bn_training=False)
            label_pred_q = F.softmax(label_logits_q[:,:-1], dim=1).argmax(dim=1)
            label_pred_q_correct = torch.eq(label_pred_q, y_qry).sum().item()
            corrects["query_nway_recall"][0] += label_pred_q_correct

            unlabel_logits_q = self.net(unlabel_qry, self.net.parameters(), bn_training=False)
            unlabel_pred_q = F.softmax(unlabel_logits_q, dim=1).argmax(dim=1)
            other = torch.eq(unlabel_pred_q, qry_unlabel_label).sum().item()
            corrects["distractor_query_nway_recall"][0] += other


        # this is the loss and accuracy after the first update
        with torch.no_grad():

            total_logits_q = self.net(qry_image,fast_weights , bn_training=False)
            total_pred_q = F.softmax(total_logits_q, dim=1).argmax(dim=1)
            total_q_correct = torch.eq(total_pred_q, qry_label).sum().item()
            corrects["total_query_nway"][1] += total_q_correct
            loss_q = F.cross_entropy(total_logits_q, qry_label)

            label_logits_q = self.net(x_qry, fast_weights, bn_training=False)
            label_pred_q = F.softmax(label_logits_q[:,:-1], dim=1).argmax(dim=1)
            label_pred_q_correct = torch.eq(label_pred_q, y_qry).sum().item()
            corrects["query_nway_recall"][1] += label_pred_q_correct

            unlabel_logits_q = self.net(unlabel_qry, fast_weights, bn_training=False)
            unlabel_pred_q = F.softmax(unlabel_logits_q, dim=1).argmax(dim=1)
            other = torch.eq(unlabel_pred_q, qry_unlabel_label).sum().item()
            corrects["distractor_query_nway_recall"][1] += other


        for k in range(1, self.update_step_test):
            # 1. run the i-th task and compute loss for k=1~K-1
            logits = net(spt_image, fast_weights, bn_training=True)
            loss = F.cross_entropy(logits, spt_label)
            # 2. compute grad on theta_pi
            grad = torch.autograd.grad(loss, fast_weights)
            # 3. theta_pi = theta_pi - train_lr * grad
            fast_weights = list(map(lambda p: p[1] - self.update_lr * p[0], zip(grad, fast_weights)))

            logits_q = net(qry_image, fast_weights, bn_training=True)
            # loss_q will be overwritten and just keep the loss_q on last update step.
            loss_q = F.cross_entropy(logits_q, qry_label)

            with torch.no_grad():

                total_logits_q = self.net(qry_image,fast_weights , bn_training=False)
                total_pred_q = F.softmax(total_logits_q, dim=1).argmax(dim=1)
                total_q_correct = torch.eq(total_pred_q, qry_label).sum().item()
                corrects["total_query_nway"][k+1] += total_q_correct
                loss_q = F.cross_entropy(total_logits_q, qry_label)

                label_logits_q = self.net(x_qry, fast_weights, bn_training=False)
                label_pred_q = F.softmax(label_logits_q[:,:-1], dim=1).argmax(dim=1)
                label_pred_q_correct = torch.eq(label_pred_q, y_qry).sum().item()
                corrects["query_nway_recall"][k+1] += label_pred_q_correct

                unlabel_logits_q = self.net(unlabel_qry, fast_weights, bn_training=False)
                unlabel_pred_q = F.softmax(unlabel_logits_q, dim=1).argmax(dim=1)
                other = torch.eq(unlabel_pred_q, qry_unlabel_label).sum().item()
                corrects["distractor_query_nway_recall"][k+1] += other
        del net
        accs = {}

        accs["total_query_nway"] = corrects["total_query_nway"] / (querysz + unlabel_querysz)
        accs["query_nway_recall"] = corrects["query_nway_recall"] / querysz
        accs["distractor_query_nway_recall"] = corrects["distractor_query_nway_recall"] / (unlabel_querysz)

        return accs

# %%
device = torch.device("cuda")
maml = Meta(args, config).to(device)

# %%
tmp = filter(lambda x: x.requires_grad, maml.parameters())
num = sum(map(lambda x: np.prod(x.shape), tmp))

# %%
path = args["save_path"]
step = 0
mkdir_p(path)
for epoch in range(args["epoch"]//6000):
        # fetch meta_batchsz num of episode each time

    train_dataloader = DataLoader(train_data_generator, args["task_num"], shuffle=True, num_workers=1, pin_memory=True)
    x_spt = y_spt = x_qry = y_qry = unlabel_spt = unlabel_qry = gan_qry = gan_spt = 0
    for idx,data  in enumerate(train_dataloader):
        if args["gan"]:
            with torch.no_grad():
                gan_spt_noise = torch.randn(args["task_num"]*args["spy_gan_num"], 100, 1, 1, device=device)
                gan_spt = netG(gan_spt_noise).to(device).view(args["task_num"],args["spy_gan_num"],args["img_c"],args["img_sz"],args["img_sz"])
                gan_qry_noise = torch.randn(args["task_num"]*args["qry_gan_num"], 100, 1, 1, device=device)
                gan_qry = netG(gan_qry_noise).to(device).view(args["task_num"],args["qry_gan_num"],args["img_c"],args["img_sz"],args["img_sz"])
        if len(data) == 4:
            (x_spt, y_spt, x_qry, y_qry) = data
            x_spt, y_spt, x_qry, y_qry = x_spt.to(device), y_spt.to(device), x_qry.to(device), y_qry.to(device)
            if args["gan"]:
                accs,loss_q = maml(x_spt, y_spt, x_qry, y_qry,step,gan_spt=gan_spt, gan_qry=gan_qry)
            else:
                accs,loss_q = maml(x_spt, y_spt, x_qry, y_qry,step)
        else:
            (x_spt, y_spt, x_qry, y_qry, unlabel_spt, unlabel_qry) = data
            x_spt, y_spt, x_qry, y_qry, unlabel_spt, unlabel_qry = x_spt.to(device), y_spt.to(device), x_qry.to(device), y_qry.to(device), \
            unlabel_spt.to(device), unlabel_qry.to(device)
            if args["spy_gan_num"]:
                accs,loss_q = maml(x_spt, y_spt, x_qry, y_qry,step,unlabel_spt_image=unlabel_spt, unlabel_qry_image=unlabel_qry,gan_spt=gan_spt, gan_qry=gan_qry)
            else:
                accs,loss_q = maml(x_spt, y_spt, x_qry, y_qry,step,unlabel_spt_image=unlabel_spt, unlabel_qry_image=unlabel_qry)

        writer.add_scalar("Loss/train_loss", loss_q, step)
        if "total_query_nway" in accs:
            writer.add_scalar("Accuracy/train_total_query_nway", accs["total_query_nway"][-1], step)
        if "label_query_nway_recall" in accs:
            writer.add_scalar("Accuracy/train_label_query_nway_recall", accs["label_query_nway_recall"][-1], step)
        if "distractor_query_nway_recall" in accs:
            writer.add_scalar("Accuracy/train_distractor_query_nway_recall", accs["distractor_query_nway_recall"][-1], step)
        if "query_nway_recall" in accs:
            writer.add_scalar("Accuracy/train_query_nway_recall", accs["query_nway_recall"][-1], step)
        if "gan_query_nway_recall" in accs:
            writer.add_scalar("Accuracy/train_gan_query_nway_recall", accs["gan_query_nway_recall"][-1], step)
        if "query_nway" in accs:
            writer.add_scalar("Accuracy/train_query_nway_recall", accs["query_nway_recall"][-1], step)
        if step % 30 == 0:
            print("step:", step, "\ttraining acc:", accs)
        if step % 100 == 0:  # evaluation
            db_test = DataLoader(test_data_generator, 1, shuffle=True, num_workers=1, pin_memory=True)
            accs_all_test = {
                            "total_query_nway":[],
                            "distractor_query_nway_recall":[],
                            "query_nway_recall":[],
                            "label_query_nway_recall":[],
                            "gan_query_nway":[]
            }
            for test_data in db_test:
                if args["gan"]:
                    gan_spt_noise = torch.randn(args["spy_gan_num"], 100, 1, 1, device=device)
                    gan_spt = netG(gan_spt_noise).to(device)
                    gan_qry_noise = torch.randn(args["qry_gan_num"], 100, 1, 1, device=device)
                    gan_qry = netG(gan_qry_noise).to(device)
                if len(test_data) == 4:
                    x_spt, y_spt, x_qry, y_qry = test_data
                    x_spt, y_spt, x_qry, y_qry = x_spt.squeeze(0).to(device), y_spt.squeeze(0).to(device), \
                                                 x_qry.squeeze(0).to(device), y_qry.squeeze(0).to(device)
                    if args["gan"]:
                        accs,loss_q = maml.finetunning(x_spt, y_spt, x_qry, y_qry,gan_spt=gan_spt, gan_qry=gan_qry)
                    else:
                        accs = maml.finetunning(x_spt, y_spt, x_qry, y_qry)

                else:
                    x_spt, y_spt, x_qry, y_qry, unlabel_spt, unlabel_qry = test_data
                    x_spt, y_spt, x_qry, y_qry, unlabel_spt, unlabel_qry = x_spt.squeeze(0).to(device), y_spt.squeeze(0).to(device), \
                                                 x_qry.squeeze(0).to(device), y_qry.squeeze(0).to(device),\
                                                unlabel_spt.squeeze(0).to(device), unlabel_qry.squeeze(0).to(device)
                    if args["gan"]:
                        accs = maml.finetunning(x_spt, y_spt, x_qry, y_qry, unlabel_spt, unlabel_qry,gan_spt=gan_spt, gan_qry=gan_qry)
                    else:
                        accs = maml.finetunning(x_spt, y_spt, x_qry, y_qry, unlabel_spt, unlabel_qry)
                if "total_query_nway" in accs:
                    accs_all_test["total_query_nway"].append(accs["total_query_nway"])
                if "label_query_nway_recall" in accs:
                    accs_all_test["label_query_nway_recall"].append(accs["label_query_nway_recall"])
                if "distractor_query_nway_recall" in accs:
                    accs_all_test["distractor_query_nway_recall"].append(accs["distractor_query_nway_recall"])
                if "gan_query_nway" in accs:
                    accs_all_test["gan_query_nway"].append(accs["gan_query_nway"])
                if "query_nway_recall" in accs:
                    accs_all_test["query_nway_recall"].append(accs["query_nway_recall"])
            # [b, update_step+1]
            if "total_query_nway" in accs:
                accs["total_query_nway"] = np.array(accs_all_test["total_query_nway"]).mean(axis=0).astype(np.float16)
                writer.add_scalar("Accuracy/test_total_query_nway_accuracy", accs["total_query_nway"][-1], step)
            if "label_query_nway_recall" in accs:
                accs["label_query_nway_recall"] = np.array(accs_all_test["label_query_nway_recall"]).mean(axis=0).astype(np.float16)
                
                writer.add_scalar("Accuracy/test_label_query_nway_accuracy", accs["label_query_nway_recall"][-1], step)
            if "distractor_query_nway_recall" in accs:
                accs["distractor_query_nway_recall"] = np.array(accs_all_test["distractor_query_nway_recall"]).mean(axis=0).astype(np.float16)
                writer.add_scalar("Accuracy/test_distractor_query_nway_recall_accuracy", accs["distractor_query_nway_recall"][-1], step)
            if "gan_query_nway" in accs:
                accs["gan_query_nway"] = np.array(accs_all_test["gan_query_nway"]).mean(axis=0).astype(np.float16)
                writer.add_scalar("Accuracy/test_gan_query_nway_accuracy", accs["gan_query_nway"][-1], step)
            if "query_nway_recall" in accs:
                accs["query_nway_recall"] = np.array(accs_all_test["query_nway_recall"]).mean(axis=0).astype(np.float16)
                writer.add_scalar("Accuracy/test_query_nway_accuracy", accs["query_nway_recall"][-1], step)
            print(step)
            print("Test acc:", accs)

            torch.save(maml.state_dict(), "model_results/" + path + "/model_step" + str(step) + ".pt")
        step += 1
# Out:
# step: 0 	training acc: {'total_query_nway': array([0.09272727, 0.17818182, 0.3       , 0.34727273, 0.38545455,
#        0.41636364]), 'label_query_nway_recall': array([0.192, 0.356, 0.448, 0.5  , 0.556, 0.624]), 'query_nway_recall': array([0.192, 0.364, 0.472, 0.52 , 0.592, 0.652]), 'distractor_query_nway_recall': array([0.01      , 0.03      , 0.17666667, 0.22333333, 0.24333333,
#        0.24333333])}
# 0
# Test acc: {'total_query_nway': array([0.    , 0.523 , 0.4172, 0.4546, 0.4756, 0.491 , 0.501 , 0.514 ,
#        0.5205, 0.527 , 0.5337], dtype=float16), 'query_nway_recall': array([0.2078, 0.4062, 0.4873, 0.5273, 0.5503, 0.5664, 0.578 , 0.593 ,
#        0.6006, 0.607 , 0.6133], dtype=float16), 'distractor_query_nway_recall': array([0.08624, 0.11   , 0.1338 , 0.1525 , 0.16   , 0.165  , 0.17   ,
#        0.1787 , 0.18   , 0.1837 , 0.19   ], dtype=float16)}
# step: 30 	training acc: {'total_query_nway': array([0.54363636, 0.54727273, 0.54545455, 0.54363636, 0.57090909,
#        0.58909091]), 'label_query_nway_recall': array([0.   , 0.024, 0.052, 0.076, 0.152, 0.272]), 'query_nway_recall': array([0.184, 0.444, 0.56 , 0.58 , 0.604, 0.608]), 'distractor_query_nway_recall': array([0.99666667, 0.98333333, 0.95666667, 0.93333333, 0.92      ,
#        0.85333333])}
# step: 60 	training acc: {'total_query_nway': array([0.54      , 0.53454545, 0.53272727, 0.56545455, 0.61272727,
#        0.60909091]), 'label_query_nway_recall': array([0.008, 0.02 , 0.04 , 0.14 , 0.304, 0.408]), 'query_nway_recall': array([0.16 , 0.436, 0.564, 0.62 , 0.644, 0.676]), 'distractor_query_nway_recall': array([0.98333333, 0.96333333, 0.94333333, 0.92      , 0.87      ,
#        0.77666667])}
# step: 90 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.55818182, 0.59090909, 0.64181818,
#        0.66545455]), 'label_query_nway_recall': array([0.   , 0.   , 0.036, 0.132, 0.28 , 0.404]), 'query_nway_recall': array([0.196, 0.456, 0.564, 0.624, 0.64 , 0.676]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99333333, 0.97333333, 0.94333333,
#        0.88333333])}
# 100
# Test acc: {'total_query_nway': array([0.    , 0.3333, 0.1871, 0.3118, 0.4065, 0.4595, 0.5005, 0.521 ,
#        0.5425, 0.5547, 0.567 ], dtype=float16), 'query_nway_recall': array([0.1805, 0.4368, 0.56  , 0.602 , 0.636 , 0.6455, 0.655 , 0.6626,
#        0.668 , 0.6714, 0.6743], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.9985, 0.971 , 0.939 , 0.8926, 0.8735, 0.84  ,
#        0.825 , 0.8037, 0.785 ], dtype=float16)}
# step: 120 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54727273, 0.56181818, 0.61454545,
#        0.62909091]), 'label_query_nway_recall': array([0.   , 0.   , 0.004, 0.052, 0.204, 0.296]), 'query_nway_recall': array([0.212, 0.456, 0.54 , 0.616, 0.624, 0.636]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98666667, 0.95666667,
#        0.90666667])}
# step: 150 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.55636364, 0.59818182, 0.61090909,
#        0.61454545]), 'label_query_nway_recall': array([0.   , 0.   , 0.028, 0.164, 0.316, 0.396]), 'query_nway_recall': array([0.212, 0.368, 0.528, 0.616, 0.644, 0.66 ]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99666667, 0.96      , 0.85666667,
#        0.79666667])}
# step: 180 	training acc: {'total_query_nway': array([0.54545455, 0.55272727, 0.57090909, 0.62545455, 0.62545455,
#        0.63818182]), 'label_query_nway_recall': array([0.   , 0.016, 0.072, 0.224, 0.3  , 0.376]), 'query_nway_recall': array([0.208, 0.384, 0.52 , 0.608, 0.632, 0.648]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99      , 0.96      , 0.89666667,
#        0.85666667])}
# 200
# Test acc: {'total_query_nway': array([0.    , 0.3333, 0.1967, 0.3784, 0.521 , 0.59  , 0.622 , 0.645 ,
#        0.6562, 0.6646, 0.672 ], dtype=float16), 'query_nway_recall': array([0.1782, 0.4978, 0.628 , 0.675 , 0.706 , 0.727 , 0.7383, 0.747 ,
#        0.7524, 0.754 , 0.7563], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.995 , 0.965 , 0.916 , 0.8677, 0.8325, 0.7876,
#        0.7637, 0.7437, 0.73  ], dtype=float16)}
# step: 210 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54727273, 0.60909091, 0.73090909,
#        0.74727273]), 'label_query_nway_recall': array([0.   , 0.   , 0.004, 0.144, 0.468, 0.556]), 'query_nway_recall': array([0.168, 0.492, 0.652, 0.704, 0.74 , 0.752]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99666667, 0.95      ,
#        0.90666667])}
# step: 240 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54909091, 0.62545455, 0.69636364,
#        0.74727273]), 'label_query_nway_recall': array([0.   , 0.   , 0.008, 0.176, 0.424, 0.608]), 'query_nway_recall': array([0.184, 0.488, 0.692, 0.716, 0.748, 0.76 ]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 1.        , 0.92      ,
#        0.86333333])}
# step: 270 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54181818, 0.57636364, 0.61272727,
#        0.63818182]), 'label_query_nway_recall': array([0.   , 0.   , 0.004, 0.14 , 0.288, 0.408]), 'query_nway_recall': array([0.204, 0.368, 0.484, 0.552, 0.596, 0.628]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99      , 0.94      , 0.88333333,
#        0.83      ])}
# step: 300 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54363636, 0.57454545, 0.64      ,
#        0.69090909]), 'label_query_nway_recall': array([0.   , 0.   , 0.   , 0.144, 0.408, 0.588]), 'query_nway_recall': array([0.212, 0.46 , 0.584, 0.636, 0.672, 0.724]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99666667, 0.93333333, 0.83333333,
#        0.77666667])}
# 300
# Test acc: {'total_query_nway': array([0.    , 0.3342, 0.2043, 0.4128, 0.555 , 0.6255, 0.655 , 0.6704,
#        0.6846, 0.6904, 0.696 ], dtype=float16), 'query_nway_recall': array([0.2078, 0.5283, 0.64  , 0.6807, 0.722 , 0.7437, 0.7554, 0.7656,
#        0.771 , 0.773 , 0.774 ], dtype=float16), 'distractor_query_nway_recall': array([0.9985, 1.    , 0.995 , 0.9663, 0.89  , 0.839 , 0.786 , 0.7324,
#        0.7124, 0.69  , 0.675 ], dtype=float16)}
# step: 330 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.56727273, 0.59454545, 0.64545455,
#        0.69454545]), 'label_query_nway_recall': array([0.   , 0.   , 0.048, 0.108, 0.24 , 0.452]), 'query_nway_recall': array([0.148, 0.524, 0.616, 0.68 , 0.716, 0.736]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 1.        , 0.98333333,
#        0.89666667])}
# step: 360 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.55454545, 0.6       , 0.62      ,
#        0.64909091]), 'label_query_nway_recall': array([0.   , 0.   , 0.02 , 0.168, 0.404, 0.532]), 'query_nway_recall': array([0.2  , 0.496, 0.608, 0.672, 0.724, 0.764]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.96      , 0.8       ,
#        0.74666667])}
# step: 390 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54545455, 0.65090909, 0.72181818,
#        0.75818182]), 'label_query_nway_recall': array([0.   , 0.   , 0.   , 0.256, 0.52 , 0.664]), 'query_nway_recall': array([0.224, 0.532, 0.656, 0.74 , 0.776, 0.816]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98      , 0.89      ,
#        0.83666667])}
# 400
# Test acc: {'total_query_nway': array([0.    , 0.3333, 0.1748, 0.3704, 0.506 , 0.57  , 0.6016, 0.6226,
#        0.6333, 0.6465, 0.654 ], dtype=float16), 'query_nway_recall': array([0.2032, 0.512 , 0.621 , 0.6577, 0.689 , 0.7075, 0.7217, 0.7295,
#        0.734 , 0.7383, 0.742 ], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.9985, 0.9785, 0.915 , 0.8364, 0.7773, 0.7427,
#        0.72  , 0.71  , 0.6924], dtype=float16)}
# step: 420 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.55272727, 0.62181818, 0.66      ,
#        0.69454545]), 'label_query_nway_recall': array([0.   , 0.   , 0.016, 0.184, 0.308, 0.448]), 'query_nway_recall': array([0.144, 0.356, 0.492, 0.544, 0.604, 0.628]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98666667, 0.95333333,
#        0.9       ])}
# step: 450 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54545455, 0.59636364, 0.73090909,
#        0.74181818]), 'label_query_nway_recall': array([0.   , 0.   , 0.   , 0.136, 0.456, 0.548]), 'query_nway_recall': array([0.224, 0.548, 0.676, 0.7  , 0.744, 0.768]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98      , 0.96      ,
#        0.90333333])}
# step: 480 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54545455, 0.62909091, 0.70363636,
#        0.73636364]), 'label_query_nway_recall': array([0.   , 0.   , 0.   , 0.204, 0.404, 0.552]), 'query_nway_recall': array([0.176, 0.528, 0.608, 0.64 , 0.728, 0.764]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98333333, 0.95333333,
#        0.89      ])}
# 500
# Test acc: {'total_query_nway': array([0.    , 0.3333, 0.1884, 0.4   , 0.5586, 0.627 , 0.6655, 0.6865,
#        0.6987, 0.7075, 0.714 ], dtype=float16), 'query_nway_recall': array([0.1952, 0.5454, 0.672 , 0.712 , 0.7476, 0.7666, 0.778 , 0.783 ,
#        0.788 , 0.791 , 0.7983], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.9985, 0.98  , 0.931 , 0.875 , 0.845 , 0.8174,
#        0.79  , 0.7637, 0.7476], dtype=float16)}
# step: 510 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54545455, 0.60545455, 0.68545455,
#        0.70181818]), 'label_query_nway_recall': array([0.   , 0.   , 0.   , 0.144, 0.348, 0.44 ]), 'query_nway_recall': array([0.176, 0.372, 0.552, 0.62 , 0.624, 0.636]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99      , 0.96666667,
#        0.92      ])}
# step: 540 	training acc: {'total_query_nway': array([0.54545455, 0.54363636, 0.57272727, 0.63090909, 0.68363636,
#        0.71090909]), 'label_query_nway_recall': array([0.   , 0.   , 0.064, 0.196, 0.38 , 0.492]), 'query_nway_recall': array([0.192, 0.52 , 0.616, 0.648, 0.684, 0.7  ]), 'distractor_query_nway_recall': array([1.        , 0.99666667, 0.99666667, 0.99333333, 0.93666667,
#        0.89333333])}
# step: 570 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54545455, 0.65090909, 0.72363636,
#        0.76545455]), 'label_query_nway_recall': array([0.   , 0.   , 0.   , 0.236, 0.436, 0.572]), 'query_nway_recall': array([0.18 , 0.516, 0.632, 0.68 , 0.72 , 0.772]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99666667, 0.96333333,
#        0.92666667])}
# step: 600 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.55454545, 0.65272727, 0.72545455,
#        0.76727273]), 'label_query_nway_recall': array([0.   , 0.   , 0.02 , 0.244, 0.456, 0.588]), 'query_nway_recall': array([0.324, 0.644, 0.728, 0.744, 0.788, 0.8  ]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99333333, 0.95      ,
#        0.91666667])}
# 600
# Test acc: {'total_query_nway': array([0.    , 0.3333, 0.2054, 0.4978, 0.6333, 0.7   , 0.7285, 0.7466,
#        0.7593, 0.7676, 0.771 ], dtype=float16), 'query_nway_recall': array([0.2073, 0.5864, 0.718 , 0.7656, 0.8037, 0.8223, 0.829 , 0.8354,
#        0.839 , 0.842 , 0.8447], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.9985, 0.964 , 0.9077, 0.865 , 0.826 , 0.806 ,
#        0.7925, 0.7837, 0.7725], dtype=float16)}
# step: 630 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.55090909, 0.67272727, 0.73636364,
#        0.77818182]), 'label_query_nway_recall': array([0.   , 0.   , 0.012, 0.288, 0.496, 0.624]), 'query_nway_recall': array([0.176, 0.568, 0.692, 0.728, 0.764, 0.792]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99333333, 0.93666667,
#        0.90666667])}
# step: 660 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54545455, 0.63454545, 0.77090909,
#        0.78      ]), 'label_query_nway_recall': array([0.   , 0.   , 0.   , 0.212, 0.58 , 0.692]), 'query_nway_recall': array([0.148, 0.552, 0.756, 0.804, 0.836, 0.844]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98666667, 0.93      ,
#        0.85333333])}
# step: 690 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.57090909, 0.61636364, 0.64545455,
#        0.65090909]), 'label_query_nway_recall': array([0.   , 0.   , 0.068, 0.208, 0.304, 0.372]), 'query_nway_recall': array([0.18 , 0.464, 0.568, 0.588, 0.608, 0.62 ]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99      , 0.95666667, 0.93      ,
#        0.88333333])}
# 700
# Test acc: {'total_query_nway': array([0.    , 0.3352, 0.2563, 0.583 , 0.674 , 0.7026, 0.7217, 0.736 ,
#        0.7456, 0.752 , 0.7544], dtype=float16), 'query_nway_recall': array([0.2032, 0.5986, 0.6934, 0.735 , 0.761 , 0.783 , 0.7964, 0.8057,
#        0.815 , 0.8184, 0.8203], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.9814, 0.865 , 0.76  , 0.6973, 0.661 , 0.636 ,
#        0.6274, 0.6187, 0.609 ], dtype=float16)}
# step: 720 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.55818182, 0.63454545, 0.70363636,
#        0.71454545]), 'label_query_nway_recall': array([0.   , 0.   , 0.028, 0.216, 0.488, 0.576]), 'query_nway_recall': array([0.14 , 0.5  , 0.728, 0.72 , 0.752, 0.776]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98333333, 0.88333333,
#        0.83      ])}
# step: 750 	training acc: {'total_query_nway': array([0.54545455, 0.54363636, 0.57454545, 0.67454545, 0.72909091,
#        0.75454545]), 'label_query_nway_recall': array([0.   , 0.   , 0.068, 0.328, 0.56 , 0.66 ]), 'query_nway_recall': array([0.248, 0.604, 0.74 , 0.784, 0.796, 0.796]), 'distractor_query_nway_recall': array([1.        , 0.99666667, 0.99666667, 0.96333333, 0.87      ,
#        0.83      ])}
# step: 780 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54727273, 0.67636364, 0.78181818,
#        0.84363636]), 'label_query_nway_recall': array([0.   , 0.   , 0.004, 0.324, 0.568, 0.708]), 'query_nway_recall': array([0.216, 0.736, 0.808, 0.848, 0.884, 0.916]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.97      , 0.96      ,
#        0.95666667])}
# 800
# Test acc: {'total_query_nway': array([0.    , 0.3352, 0.3054, 0.5747, 0.6846, 0.7256, 0.7515, 0.765 ,
#        0.7764, 0.786 , 0.791 ], dtype=float16), 'query_nway_recall': array([0.197 , 0.606 , 0.728 , 0.772 , 0.8145, 0.834 , 0.8486, 0.856 ,
#        0.86  , 0.8643, 0.8667], dtype=float16), 'distractor_query_nway_recall': array([1.    , 0.9985, 0.985 , 0.925 , 0.8413, 0.791 , 0.77  , 0.76  ,
#        0.754 , 0.746 , 0.7363], dtype=float16)}
# step: 810 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.57454545, 0.75090909, 0.81818182,
#        0.85272727]), 'label_query_nway_recall': array([0.   , 0.   , 0.064, 0.472, 0.728, 0.84 ]), 'query_nway_recall': array([0.244, 0.732, 0.904, 0.94 , 0.968, 0.964]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98333333, 0.89333333,
#        0.86333333])}
# step: 840 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.55818182, 0.62909091, 0.72545455,
#        0.73636364]), 'label_query_nway_recall': array([0.   , 0.   , 0.028, 0.228, 0.496, 0.576]), 'query_nway_recall': array([0.172, 0.444, 0.592, 0.648, 0.668, 0.688]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.96333333, 0.91666667,
#        0.87      ])}
# step: 870 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.56181818, 0.66363636, 0.69272727,
#        0.72363636]), 'label_query_nway_recall': array([0.   , 0.   , 0.036, 0.28 , 0.4  , 0.512]), 'query_nway_recall': array([0.216, 0.544, 0.652, 0.668, 0.704, 0.732]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98333333, 0.93666667,
#        0.9       ])}
# step: 900 	training acc: {'total_query_nway': array([0.54545455, 0.55090909, 0.57636364, 0.72545455, 0.77636364,
#        0.79090909]), 'label_query_nway_recall': array([0.   , 0.012, 0.068, 0.452, 0.644, 0.74 ]), 'query_nway_recall': array([0.148, 0.564, 0.712, 0.756, 0.8  , 0.836]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.95333333, 0.88666667,
#        0.83333333])}
# 900
# Test acc: {'total_query_nway': array([0.    , 0.3333, 0.237 , 0.54  , 0.6743, 0.7314, 0.7563, 0.775 ,
#        0.7876, 0.7974, 0.802 ], dtype=float16), 'query_nway_recall': array([0.2063, 0.6567, 0.772 , 0.8154, 0.8457, 0.859 , 0.8677, 0.874 ,
#        0.879 , 0.8823, 0.8843], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.9976, 0.965 , 0.9087, 0.8823, 0.851 , 0.83  ,
#        0.8174, 0.8013, 0.7964], dtype=float16)}
# step: 930 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54545455, 0.64181818, 0.67454545,
#        0.68      ]), 'label_query_nway_recall': array([0.   , 0.   , 0.   , 0.264, 0.388, 0.456]), 'query_nway_recall': array([0.228, 0.452, 0.572, 0.596, 0.608, 0.636]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.95666667, 0.91333333,
#        0.86666667])}
# step: 960 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54727273, 0.70727273, 0.81454545,
#        0.83090909]), 'label_query_nway_recall': array([0.   , 0.   , 0.004, 0.376, 0.668, 0.752]), 'query_nway_recall': array([0.16 , 0.672, 0.816, 0.848, 0.876, 0.888]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98333333, 0.93666667,
#        0.89666667])}
# step: 990 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.54909091, 0.72363636, 0.76727273,
#        0.79636364]), 'label_query_nway_recall': array([0.   , 0.   , 0.008, 0.444, 0.6  , 0.704]), 'query_nway_recall': array([0.148, 0.712, 0.824, 0.844, 0.872, 0.88 ]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.95666667, 0.90666667,
#        0.87333333])}
# 1000
# Test acc: {'total_query_nway': array([0.    , 0.3352, 0.315 , 0.635 , 0.734 , 0.7695, 0.7876, 0.7983,
#        0.8105, 0.8154, 0.82  ], dtype=float16), 'query_nway_recall': array([0.195 , 0.676 , 0.786 , 0.83  , 0.858 , 0.873 , 0.8813, 0.884 ,
#        0.887 , 0.8887, 0.8906], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.98  , 0.9014, 0.8613, 0.8325, 0.814 , 0.8013,
#        0.7974, 0.7837, 0.779 ], dtype=float16)}
# step: 1020 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.57454545, 0.65454545, 0.75636364,
#        0.78545455]), 'label_query_nway_recall': array([0.   , 0.   , 0.064, 0.256, 0.5  , 0.648]), 'query_nway_recall': array([0.184, 0.628, 0.768, 0.78 , 0.816, 0.832]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98666667, 0.97      ,
#        0.9       ])}
# step: 1050 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.56363636, 0.70727273, 0.8       ,
#        0.82727273]), 'label_query_nway_recall': array([0.   , 0.   , 0.04 , 0.364, 0.596, 0.688]), 'query_nway_recall': array([0.188, 0.628, 0.74 , 0.776, 0.824, 0.848]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99333333, 0.97      ,
#        0.94333333])}
# step: 1080 	training acc: {'total_query_nway': array([0.54727273, 0.55636364, 0.57818182, 0.69454545, 0.72727273,
#        0.76181818]), 'label_query_nway_recall': array([0.004, 0.024, 0.072, 0.36 , 0.484, 0.588]), 'query_nway_recall': array([0.304, 0.616, 0.68 , 0.736, 0.744, 0.764]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.97333333, 0.93      ,
#        0.90666667])}
# 1100
# Test acc: {'total_query_nway': array([0.    , 0.3333, 0.291 , 0.5894, 0.6895, 0.7344, 0.752 , 0.761 ,
#        0.77  , 0.7773, 0.7837], dtype=float16), 'query_nway_recall': array([0.2228, 0.6597, 0.756 , 0.802 , 0.833 , 0.848 , 0.8516, 0.854 ,
#        0.8574, 0.86  , 0.862 ], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.9985, 0.9414, 0.8877, 0.845 , 0.8223, 0.8013,
#        0.786 , 0.7773, 0.7715], dtype=float16)}
# step: 1110 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.61090909, 0.73818182, 0.77090909,
#        0.77272727]), 'label_query_nway_recall': array([0.   , 0.   , 0.144, 0.444, 0.656, 0.736]), 'query_nway_recall': array([0.244, 0.704, 0.84 , 0.884, 0.928, 0.944]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98333333, 0.86666667,
#        0.80333333])}
# step: 1140 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.55090909, 0.68181818, 0.74909091,
#        0.78      ]), 'label_query_nway_recall': array([0.   , 0.   , 0.012, 0.356, 0.556, 0.668]), 'query_nway_recall': array([0.212, 0.58 , 0.704, 0.74 , 0.828, 0.848]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.95333333, 0.91      ,
#        0.87333333])}
# step: 1170 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.56727273, 0.64909091, 0.71272727,
#        0.73272727]), 'label_query_nway_recall': array([0.   , 0.   , 0.048, 0.236, 0.408, 0.496]), 'query_nway_recall': array([0.232, 0.64 , 0.708, 0.728, 0.736, 0.748]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99333333, 0.96666667,
#        0.93      ])}
# step: 1200 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.56181818, 0.62363636, 0.72363636,
#        0.74545455]), 'label_query_nway_recall': array([0.   , 0.   , 0.036, 0.18 , 0.448, 0.576]), 'query_nway_recall': array([0.172, 0.512, 0.712, 0.736, 0.756, 0.764]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99333333, 0.95333333,
#        0.88666667])}
# 1200
# Test acc: {'total_query_nway': array([0.    , 0.3474, 0.4548, 0.675 , 0.745 , 0.775 , 0.7866, 0.7974,
#        0.8066, 0.8115, 0.8154], dtype=float16), 'query_nway_recall': array([0.216 , 0.676 , 0.777 , 0.8276, 0.853 , 0.8706, 0.876 , 0.881 ,
#        0.8857, 0.8887, 0.89  ], dtype=float16), 'distractor_query_nway_recall': array([1.    , 0.996 , 0.955 , 0.8325, 0.7886, 0.755 , 0.734 , 0.721 ,
#        0.7188, 0.7188, 0.715 ], dtype=float16)}
# step: 1230 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.58363636, 0.76181818, 0.82      ,
#        0.83090909]), 'label_query_nway_recall': array([0.   , 0.   , 0.084, 0.484, 0.616, 0.684]), 'query_nway_recall': array([0.216, 0.584, 0.756, 0.788, 0.796, 0.82 ]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99333333, 0.99      ,
#        0.95333333])}
# step: 1260 	training acc: {'total_query_nway': array([0.54545455, 0.54727273, 0.6       , 0.69818182, 0.75454545,
#        0.77636364]), 'label_query_nway_recall': array([0.   , 0.004, 0.12 , 0.34 , 0.496, 0.576]), 'query_nway_recall': array([0.212, 0.604, 0.684, 0.736, 0.744, 0.768]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99666667, 0.97      ,
#        0.94333333])}
# step: 1290 	training acc: {'total_query_nway': array([0.54545455, 0.54181818, 0.55818182, 0.66909091, 0.74181818,
#        0.75090909]), 'label_query_nway_recall': array([0.   , 0.   , 0.04 , 0.32 , 0.54 , 0.612]), 'query_nway_recall': array([0.24 , 0.624, 0.736, 0.772, 0.788, 0.804]), 'distractor_query_nway_recall': array([1.        , 0.99333333, 0.99      , 0.96      , 0.91      ,
#        0.86666667])}
# 1300
# Test acc: {'total_query_nway': array([0.    , 0.3335, 0.391 , 0.6685, 0.74  , 0.766 , 0.7812, 0.7886,
#        0.796 , 0.8013, 0.804 ], dtype=float16), 'query_nway_recall': array([0.1965, 0.661 , 0.768 , 0.813 , 0.8374, 0.8486, 0.856 , 0.8604,
#        0.8647, 0.8677, 0.8696], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.99  , 0.8765, 0.7925, 0.7573, 0.735 , 0.7236,
#        0.7075, 0.6973, 0.69  ], dtype=float16)}
# step: 1320 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.60363636, 0.75636364, 0.77090909,
#        0.76909091]), 'label_query_nway_recall': array([0.   , 0.   , 0.132, 0.484, 0.58 , 0.632]), 'query_nway_recall': array([0.2  , 0.612, 0.712, 0.732, 0.736, 0.756]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99666667, 0.98333333, 0.93      ,
#        0.88333333])}
# step: 1350 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.56181818, 0.7       , 0.74363636,
#        0.74545455]), 'label_query_nway_recall': array([0.   , 0.   , 0.036, 0.344, 0.456, 0.516]), 'query_nway_recall': array([0.22 , 0.552, 0.668, 0.684, 0.684, 0.696]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99666667, 0.98333333,
#        0.93666667])}
# step: 1380 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.58909091, 0.66727273, 0.72909091,
#        0.73272727]), 'label_query_nway_recall': array([0.   , 0.   , 0.116, 0.32 , 0.544, 0.604]), 'query_nway_recall': array([0.264, 0.588, 0.688, 0.7  , 0.744, 0.756]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.98333333, 0.95666667, 0.88333333,
#        0.84      ])}
# 1400
# Test acc: {'total_query_nway': array([0.    , 0.334 , 0.4104, 0.6675, 0.7344, 0.7656, 0.789 , 0.803 ,
#        0.8125, 0.8203, 0.8247], dtype=float16), 'query_nway_recall': array([0.1842, 0.671 , 0.788 , 0.843 , 0.867 , 0.876 , 0.8857, 0.8906,
#        0.8926, 0.8965, 0.898 ], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.9863, 0.904 , 0.8613, 0.839 , 0.82  , 0.811 ,
#        0.8037, 0.7974, 0.7925], dtype=float16)}
# step: 1410 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.58727273, 0.78545455, 0.85818182,
#        0.89636364]), 'label_query_nway_recall': array([0.   , 0.   , 0.092, 0.556, 0.728, 0.836]), 'query_nway_recall': array([0.184, 0.788, 0.848, 0.884, 0.912, 0.932]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.97666667, 0.96666667,
#        0.94666667])}
# step: 1440 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.6       , 0.74909091, 0.81272727,
#        0.83454545]), 'label_query_nway_recall': array([0.   , 0.   , 0.12 , 0.472, 0.64 , 0.692]), 'query_nway_recall': array([0.204, 0.688, 0.76 , 0.8  , 0.836, 0.844]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98      , 0.95666667,
#        0.95333333])}
# step: 1470 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.59454545, 0.70181818, 0.73818182,
#        0.76727273]), 'label_query_nway_recall': array([0.   , 0.   , 0.112, 0.376, 0.492, 0.58 ]), 'query_nway_recall': array([0.204, 0.548, 0.7  , 0.72 , 0.732, 0.756]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99666667, 0.97333333, 0.94333333,
#        0.92333333])}
# step: 1500 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.59818182, 0.75454545, 0.76545455,
#        0.76363636]), 'label_query_nway_recall': array([0.   , 0.   , 0.116, 0.476, 0.588, 0.636]), 'query_nway_recall': array([0.22 , 0.6  , 0.668, 0.7  , 0.752, 0.768]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98666667, 0.91333333,
#        0.87      ])}
# 1500
# Test acc: {'total_query_nway': array([0.    , 0.3333, 0.313 , 0.5693, 0.665 , 0.717 , 0.7427, 0.764 ,
#        0.7783, 0.7886, 0.798 ], dtype=float16), 'query_nway_recall': array([0.207 , 0.704 , 0.7983, 0.8486, 0.8716, 0.8857, 0.89  , 0.894 ,
#        0.896 , 0.898 , 0.899 ], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.9976, 0.971 , 0.94  , 0.9214, 0.91  , 0.8936,
#        0.884 , 0.8765, 0.8687], dtype=float16)}
# step: 1530 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.59636364, 0.75818182, 0.79090909,
#        0.80545455]), 'label_query_nway_recall': array([0.   , 0.   , 0.112, 0.576, 0.672, 0.716]), 'query_nway_recall': array([0.24 , 0.72 , 0.82 , 0.824, 0.84 , 0.856]), 'distractor_query_nway_recall': array([1.  , 1.  , 1.  , 0.91, 0.89, 0.88])}
# step: 1560 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.61636364, 0.79272727, 0.85636364,
#        0.86727273]), 'label_query_nway_recall': array([0.   , 0.   , 0.156, 0.572, 0.756, 0.812]), 'query_nway_recall': array([0.208, 0.804, 0.9  , 0.908, 0.932, 0.932]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.97666667, 0.94      ,
#        0.91333333])}
# step: 1590 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.61818182, 0.76363636, 0.79090909,
#        0.81090909]), 'label_query_nway_recall': array([0.   , 0.   , 0.16 , 0.528, 0.648, 0.736]), 'query_nway_recall': array([0.12 , 0.62 , 0.78 , 0.828, 0.84 , 0.852]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.96      , 0.91      ,
#        0.87333333])}
# 1600
# Test acc: {'total_query_nway': array([0.    , 0.3335, 0.4055, 0.665 , 0.7446, 0.773 , 0.7896, 0.8   ,
#        0.8066, 0.812 , 0.8154], dtype=float16), 'query_nway_recall': array([0.1777, 0.7183, 0.8174, 0.8613, 0.8794, 0.885 , 0.888 , 0.8916,
#        0.893 , 0.895 , 0.8955], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.985 , 0.931 , 0.8975, 0.8613, 0.8486, 0.8438,
#        0.834 , 0.82  , 0.811 ], dtype=float16)}
# step: 1620 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.6       , 0.73454545, 0.79272727,
#        0.81454545]), 'label_query_nway_recall': array([0.   , 0.   , 0.128, 0.48 , 0.62 , 0.676]), 'query_nway_recall': array([0.148, 0.604, 0.776, 0.808, 0.804, 0.816]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99333333, 0.94666667, 0.93666667,
#        0.93      ])}
# step: 1650 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.60181818, 0.74727273, 0.81272727,
#        0.83272727]), 'label_query_nway_recall': array([0.   , 0.   , 0.124, 0.456, 0.656, 0.732]), 'query_nway_recall': array([0.132, 0.704, 0.804, 0.852, 0.916, 0.924]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99      , 0.94333333,
#        0.91666667])}
# step: 1680 	training acc: {'total_query_nway': array([0.54545455, 0.56      , 0.60909091, 0.69454545, 0.73272727,
#        0.76363636]), 'label_query_nway_recall': array([0.   , 0.032, 0.14 , 0.42 , 0.56 , 0.64 ]), 'query_nway_recall': array([0.216, 0.676, 0.756, 0.792, 0.824, 0.84 ]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.92333333, 0.87666667,
#        0.86666667])}
# 1700
# Test acc: {'total_query_nway': array([0.    , 0.3367, 0.4573, 0.6963, 0.7515, 0.777 , 0.788 , 0.7944,
#        0.798 , 0.8027, 0.8066], dtype=float16), 'query_nway_recall': array([0.208 , 0.7305, 0.822 , 0.865 , 0.8765, 0.884 , 0.8877, 0.8887,
#        0.8896, 0.889 , 0.888 ], dtype=float16), 'distractor_query_nway_recall': array([0.9937, 0.9927, 0.975 , 0.886 , 0.85  , 0.826 , 0.8076, 0.791 ,
#        0.779 , 0.7686, 0.7637], dtype=float16)}
# step: 1710 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.56545455, 0.70909091, 0.71818182,
#        0.73090909]), 'label_query_nway_recall': array([0.   , 0.   , 0.048, 0.428, 0.492, 0.568]), 'query_nway_recall': array([0.176, 0.552, 0.648, 0.676, 0.7  , 0.708]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99666667, 0.94333333, 0.90666667,
#        0.87      ])}
# step: 1740 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.62363636, 0.83090909, 0.89818182,
#        0.92      ]), 'label_query_nway_recall': array([0.   , 0.   , 0.172, 0.676, 0.832, 0.884]), 'query_nway_recall': array([0.192, 0.824, 0.92 , 0.948, 0.972, 0.964]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.96      , 0.95333333,
#        0.95      ])}
# step: 1770 	training acc: {'total_query_nway': array([0.54363636, 0.54363636, 0.57818182, 0.67272727, 0.72727273,
#        0.76181818]), 'label_query_nway_recall': array([0.   , 0.   , 0.112, 0.456, 0.632, 0.704]), 'query_nway_recall': array([0.148, 0.636, 0.808, 0.832, 0.844, 0.848]), 'distractor_query_nway_recall': array([0.99666667, 0.99666667, 0.96666667, 0.85333333, 0.80666667,
#        0.81      ])}
# step: 1800 	training acc: {'total_query_nway': array([0.54545455, 0.56      , 0.61454545, 0.69636364, 0.76363636,
#        0.78      ]), 'label_query_nway_recall': array([0.   , 0.032, 0.152, 0.348, 0.532, 0.612]), 'query_nway_recall': array([0.188, 0.624, 0.732, 0.752, 0.8  , 0.796]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.98666667, 0.95666667,
#        0.92      ])}
# 1800
# Test acc: {'total_query_nway': array([0.    , 0.3352, 0.4155, 0.668 , 0.7485, 0.783 , 0.8027, 0.812 ,
#        0.8184, 0.823 , 0.8257], dtype=float16), 'query_nway_recall': array([0.2035, 0.7295, 0.822 , 0.868 , 0.8843, 0.8926, 0.8994, 0.901 ,
#        0.901 , 0.9023, 0.905 ], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.984 , 0.925 , 0.8975, 0.8765, 0.8564, 0.84  ,
#        0.8325, 0.8223, 0.814 ], dtype=float16)}
# step: 1830 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.67454545, 0.75636364, 0.76909091,
#        0.78363636]), 'label_query_nway_recall': array([0.   , 0.   , 0.296, 0.668, 0.76 , 0.828]), 'query_nway_recall': array([0.196, 0.8  , 0.876, 0.912, 0.92 , 0.924]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99      , 0.83      , 0.77666667,
#        0.74666667])}
# step: 1860 	training acc: {'total_query_nway': array([0.54545455, 0.56181818, 0.70909091, 0.84181818, 0.90363636,
#        0.92      ]), 'label_query_nway_recall': array([0.   , 0.036, 0.364, 0.68 , 0.82 , 0.86 ]), 'query_nway_recall': array([0.14 , 0.736, 0.856, 0.888, 0.908, 0.916]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99666667, 0.97666667, 0.97333333,
#        0.97      ])}
# step: 1890 	training acc: {'total_query_nway': array([0.54545455, 0.54909091, 0.61818182, 0.71818182, 0.76727273,
#        0.78545455]), 'label_query_nway_recall': array([0.   , 0.008, 0.16 , 0.476, 0.6  , 0.652]), 'query_nway_recall': array([0.14 , 0.62 , 0.712, 0.768, 0.78 , 0.8  ]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.92333333, 0.90666667,
#        0.89666667])}
# 1900
# Test acc: {'total_query_nway': array([0.    , 0.3499, 0.532 , 0.7407, 0.7925, 0.817 , 0.8335, 0.84  ,
#        0.8433, 0.847 , 0.851 ], dtype=float16), 'query_nway_recall': array([0.2157, 0.744 , 0.8364, 0.8794, 0.902 , 0.9136, 0.92  , 0.923 ,
#        0.9233, 0.9243, 0.926 ], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.956 , 0.8726, 0.834 , 0.8125, 0.806 , 0.79  ,
#        0.7827, 0.7773, 0.7764], dtype=float16)}
# step: 1920 	training acc: {'total_query_nway': array([0.54545455, 0.54727273, 0.59454545, 0.78181818, 0.85818182,
#        0.87636364]), 'label_query_nway_recall': array([0.   , 0.004, 0.108, 0.532, 0.712, 0.764]), 'query_nway_recall': array([0.216, 0.712, 0.808, 0.824, 0.876, 0.888]), 'distractor_query_nway_recall': array([1.  , 1.  , 1.  , 0.99, 0.98, 0.97])}
# step: 1950 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.67818182, 0.78727273, 0.80545455,
#        0.80727273]), 'label_query_nway_recall': array([0.   , 0.   , 0.296, 0.552, 0.608, 0.636]), 'query_nway_recall': array([0.212, 0.676, 0.72 , 0.748, 0.772, 0.776]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99666667, 0.98333333, 0.97      ,
#        0.95      ])}
# step: 1980 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.67454545, 0.86363636, 0.91272727,
#        0.91636364]), 'label_query_nway_recall': array([0.   , 0.   , 0.284, 0.756, 0.872, 0.888]), 'query_nway_recall': array([0.216, 0.872, 0.948, 0.968, 0.964, 0.964]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.95333333, 0.94666667,
#        0.94      ])}
# 2000
# Test acc: {'total_query_nway': array([0.    , 0.3381, 0.4033, 0.638 , 0.723 , 0.758 , 0.778 , 0.794 ,
#        0.804 , 0.811 , 0.8164], dtype=float16), 'query_nway_recall': array([0.1873, 0.732 , 0.8403, 0.88  , 0.8975, 0.906 , 0.909 , 0.9136,
#        0.914 , 0.9146, 0.9146], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.996 , 0.9526, 0.931 , 0.9136, 0.8887, 0.8774,
#        0.8677, 0.86  , 0.8535], dtype=float16)}
# step: 2010 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.65818182, 0.83090909, 0.88      ,
#        0.90363636]), 'label_query_nway_recall': array([0.   , 0.   , 0.248, 0.632, 0.792, 0.856]), 'query_nway_recall': array([0.18 , 0.876, 0.96 , 0.976, 0.98 , 0.976]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99666667, 0.95333333,
#        0.94333333])}
# step: 2040 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.70181818, 0.80909091, 0.82      ,
#        0.81454545]), 'label_query_nway_recall': array([0.   , 0.   , 0.344, 0.624, 0.672, 0.696]), 'query_nway_recall': array([0.244, 0.68 , 0.752, 0.76 , 0.784, 0.792]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.96      , 0.94333333,
#        0.91333333])}
# step: 2070 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.65272727, 0.80727273, 0.82727273,
#        0.84181818]), 'label_query_nway_recall': array([0.   , 0.   , 0.236, 0.58 , 0.684, 0.736]), 'query_nway_recall': array([0.244, 0.672, 0.78 , 0.84 , 0.864, 0.876]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99666667, 0.94333333,
#        0.93      ])}
# step: 2100 	training acc: {'total_query_nway': array([0.54545455, 0.54727273, 0.65636364, 0.80545455, 0.82      ,
#        0.81090909]), 'label_query_nway_recall': array([0.   , 0.004, 0.264, 0.624, 0.692, 0.732]), 'query_nway_recall': array([0.16 , 0.732, 0.796, 0.824, 0.86 , 0.86 ]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.98333333, 0.95666667, 0.92666667,
#        0.87666667])}
# 2100
# Test acc: {'total_query_nway': array([0.    , 0.343 , 0.541 , 0.75  , 0.801 , 0.8223, 0.831 , 0.838 ,
#        0.8423, 0.847 , 0.85  ], dtype=float16), 'query_nway_recall': array([0.2025, 0.7593, 0.8525, 0.892 , 0.9043, 0.912 , 0.915 , 0.9175,
#        0.9185, 0.92  , 0.92  ], dtype=float16), 'distractor_query_nway_recall': array([1.    , 0.9976, 0.9688, 0.8887, 0.8687, 0.846 , 0.831 , 0.8237,
#        0.8164, 0.811 , 0.8076], dtype=float16)}
# step: 2130 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.62545455, 0.74363636, 0.77818182,
#        0.78909091]), 'label_query_nway_recall': array([0.   , 0.   , 0.18 , 0.52 , 0.632, 0.672]), 'query_nway_recall': array([0.208, 0.712, 0.776, 0.82 , 0.84 , 0.824]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99666667, 0.93      , 0.9       ,
#        0.88666667])}
# step: 2160 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.71454545, 0.78181818, 0.79636364,
#        0.79454545]), 'label_query_nway_recall': array([0.   , 0.   , 0.38 , 0.584, 0.664, 0.704]), 'query_nway_recall': array([0.144, 0.672, 0.74 , 0.78 , 0.78 , 0.788]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99666667, 0.94666667, 0.90666667,
#        0.87      ])}
# step: 2190 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.63454545, 0.76      , 0.80545455,
#        0.80909091]), 'label_query_nway_recall': array([0.   , 0.   , 0.196, 0.5  , 0.628, 0.672]), 'query_nway_recall': array([0.3  , 0.66 , 0.76 , 0.82 , 0.816, 0.828]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.97666667, 0.95333333,
#        0.92333333])}
# 2200
# Test acc: {'total_query_nway': array([0.    , 0.3606, 0.5435, 0.733 , 0.7925, 0.8154, 0.8286, 0.8354,
#        0.8423, 0.847 , 0.85  ], dtype=float16), 'query_nway_recall': array([0.2157, 0.757 , 0.854 , 0.8916, 0.907 , 0.914 , 0.9185, 0.9214,
#        0.9243, 0.926 , 0.9263], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.9673, 0.9   , 0.879 , 0.86  , 0.85  , 0.8423,
#        0.8364, 0.835 , 0.826 ], dtype=float16)}
# step: 2220 	training acc: {'total_query_nway': array([0.54363636, 0.55090909, 0.73090909, 0.86909091, 0.87818182,
#        0.87636364]), 'label_query_nway_recall': array([0.   , 0.016, 0.412, 0.748, 0.788, 0.796]), 'query_nway_recall': array([0.3  , 0.812, 0.892, 0.888, 0.9  , 0.9  ]), 'distractor_query_nway_recall': array([0.99666667, 0.99666667, 0.99666667, 0.97      , 0.95333333,
#        0.94333333])}
# step: 2250 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.67818182, 0.80909091, 0.85090909,
#        0.86545455]), 'label_query_nway_recall': array([0.   , 0.   , 0.292, 0.592, 0.748, 0.796]), 'query_nway_recall': array([0.164, 0.816, 0.92 , 0.94 , 0.948, 0.952]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.99      , 0.93666667,
#        0.92333333])}
# step: 2280 	training acc: {'total_query_nway': array([0.54363636, 0.54363636, 0.66363636, 0.78545455, 0.82181818,
#        0.82727273]), 'label_query_nway_recall': array([0.   , 0.   , 0.272, 0.612, 0.708, 0.736]), 'query_nway_recall': array([0.232, 0.788, 0.84 , 0.852, 0.856, 0.852]), 'distractor_query_nway_recall': array([0.99666667, 0.99666667, 0.99      , 0.93      , 0.91666667,
#        0.90333333])}
# 2300
# Test acc: {'total_query_nway': array([0.    , 0.343 , 0.4866, 0.6914, 0.756 , 0.7847, 0.802 , 0.812 ,
#        0.8223, 0.825 , 0.8315], dtype=float16), 'query_nway_recall': array([0.185 , 0.781 , 0.851 , 0.8877, 0.8965, 0.901 , 0.9053, 0.9097,
#        0.911 , 0.9136, 0.9155], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.989 , 0.935 , 0.91  , 0.8965, 0.891 , 0.886 ,
#        0.88  , 0.8765, 0.8726], dtype=float16)}
# step: 2310 	training acc: {'total_query_nway': array([0.54545455, 0.56363636, 0.65090909, 0.76727273, 0.77272727,
#        0.76545455]), 'label_query_nway_recall': array([0.   , 0.04 , 0.244, 0.532, 0.56 , 0.58 ]), 'query_nway_recall': array([0.212, 0.608, 0.664, 0.724, 0.724, 0.736]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99      , 0.96333333, 0.95      ,
#        0.92      ])}
# step: 2340 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.67272727, 0.87636364, 0.90181818,
#        0.91818182]), 'label_query_nway_recall': array([0.   , 0.   , 0.28 , 0.796, 0.876, 0.924]), 'query_nway_recall': array([0.152, 0.904, 0.924, 0.932, 0.944, 0.964]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.94333333, 0.92333333,
#        0.91333333])}
# step: 2370 	training acc: {'total_query_nway': array([0.54545455, 0.56545455, 0.75090909, 0.86363636, 0.88545455,
#        0.90727273]), 'label_query_nway_recall': array([0.   , 0.044, 0.456, 0.712, 0.784, 0.852]), 'query_nway_recall': array([0.164, 0.832, 0.9  , 0.92 , 0.936, 0.936]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99666667, 0.99      , 0.97      ,
#        0.95333333])}
# step: 2400 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.72363636, 0.86363636, 0.89272727,
#        0.91818182]), 'label_query_nway_recall': array([0.   , 0.   , 0.396, 0.712, 0.776, 0.832]), 'query_nway_recall': array([0.212, 0.808, 0.856, 0.892, 0.936, 0.944]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99666667, 0.99      , 0.99      ,
#        0.99      ])}
# 2400
# Test acc: {'total_query_nway': array([0.    , 0.374 , 0.6016, 0.778 , 0.821 , 0.8335, 0.844 , 0.8516,
#        0.857 , 0.86  , 0.8633], dtype=float16), 'query_nway_recall': array([0.192 , 0.7964, 0.868 , 0.904 , 0.914 , 0.918 , 0.9214, 0.9243,
#        0.9253, 0.926 , 0.9263], dtype=float16), 'distractor_query_nway_recall': array([1.    , 0.9985, 0.97  , 0.884 , 0.8438, 0.819 , 0.815 , 0.81  ,
#        0.805 , 0.8   , 0.799 ], dtype=float16)}
# step: 2430 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.66545455, 0.80727273, 0.83636364,
#        0.84545455]), 'label_query_nway_recall': array([0.   , 0.   , 0.324, 0.636, 0.696, 0.732]), 'query_nway_recall': array([0.164, 0.74 , 0.776, 0.8  , 0.804, 0.804]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.95      , 0.95      , 0.95333333,
#        0.94      ])}
# step: 2460 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.74545455, 0.87454545, 0.91454545,
#        0.92      ]), 'label_query_nway_recall': array([0.   , 0.   , 0.444, 0.756, 0.868, 0.9  ]), 'query_nway_recall': array([0.132, 0.9  , 0.96 , 0.976, 0.992, 0.996]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99666667, 0.97333333, 0.95333333,
#        0.93666667])}
# step: 2490 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.65090909, 0.78      , 0.79636364,
#        0.81454545]), 'label_query_nway_recall': array([0.   , 0.   , 0.244, 0.6  , 0.684, 0.72 ]), 'query_nway_recall': array([0.256, 0.712, 0.796, 0.848, 0.868, 0.868]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99      , 0.93      , 0.89      ,
#        0.89333333])}
# 2500
# Test acc: {'total_query_nway': array([0.    , 0.4492, 0.679 , 0.791 , 0.817 , 0.831 , 0.8384, 0.8438,
#        0.8467, 0.851 , 0.8545], dtype=float16), 'query_nway_recall': array([0.1968, 0.7866, 0.8755, 0.905 , 0.9116, 0.9155, 0.917 , 0.919 ,
#        0.9204, 0.921 , 0.922 ], dtype=float16), 'distractor_query_nway_recall': array([0.9937, 0.9927, 0.9023, 0.8438, 0.83  , 0.8213, 0.815 , 0.8086,
#        0.8037, 0.8027, 0.8   ], dtype=float16)}
# step: 2520 	training acc: {'total_query_nway': array([0.54545455, 0.55636364, 0.63636364, 0.68181818, 0.68545455,
#        0.68909091]), 'label_query_nway_recall': array([0.   , 0.024, 0.204, 0.356, 0.416, 0.456]), 'query_nway_recall': array([0.216, 0.536, 0.608, 0.636, 0.648, 0.652]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99666667, 0.95333333, 0.91      ,
#        0.88333333])}
# step: 2550 	training acc: {'total_query_nway': array([0.54363636, 0.55818182, 0.63090909, 0.73272727, 0.77090909,
#        0.79454545]), 'label_query_nway_recall': array([0.   , 0.036, 0.2  , 0.484, 0.596, 0.66 ]), 'query_nway_recall': array([0.22 , 0.652, 0.736, 0.792, 0.812, 0.832]), 'distractor_query_nway_recall': array([0.99666667, 0.99333333, 0.99      , 0.94      , 0.91666667,
#        0.90666667])}
# step: 2580 	training acc: {'total_query_nway': array([0.54545455, 0.54545455, 0.75636364, 0.86      , 0.89818182,
#        0.90727273]), 'label_query_nway_recall': array([0.   , 0.   , 0.464, 0.72 , 0.82 , 0.844]), 'query_nway_recall': array([0.192, 0.808, 0.884, 0.916, 0.928, 0.928]), 'distractor_query_nway_recall': array([1.        , 1.        , 1.        , 0.97666667, 0.96333333,
#        0.96      ])}
# 2600
# Test acc: {'total_query_nway': array([0.    , 0.351 , 0.575 , 0.7207, 0.762 , 0.787 , 0.803 , 0.815 ,
#        0.8223, 0.8267, 0.8325], dtype=float16), 'query_nway_recall': array([0.2015, 0.7876, 0.8604, 0.894 , 0.901 , 0.9067, 0.9116, 0.914 ,
#        0.916 , 0.917 , 0.9194], dtype=float16), 'distractor_query_nway_recall': array([1.    , 1.    , 0.9736, 0.9224, 0.9023, 0.8936, 0.89  , 0.885 ,
#        0.8823, 0.879 , 0.875 ], dtype=float16)}
# step: 2610 	training acc: {'total_query_nway': array([0.54545455, 0.56727273, 0.71636364, 0.80727273, 0.83818182,
#        0.84      ]), 'label_query_nway_recall': array([0.   , 0.048, 0.404, 0.684, 0.752, 0.78 ]), 'query_nway_recall': array([0.152, 0.804, 0.828, 0.872, 0.888, 0.884]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.97666667, 0.91      , 0.91      ,
#        0.89      ])}
# step: 2640 	training acc: {'total_query_nway': array([0.54545455, 0.54727273, 0.62181818, 0.74363636, 0.77636364,
#        0.78545455]), 'label_query_nway_recall': array([0.   , 0.004, 0.188, 0.488, 0.576, 0.616]), 'query_nway_recall': array([0.188, 0.612, 0.728, 0.776, 0.772, 0.772]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.98333333, 0.95666667, 0.94333333,
#        0.92666667])}
# ...
#        0.84666667])}
# 11100
# Test acc: {'total_query_nway': array([0.    , 0.726 , 0.7524, 0.7744, 0.7886, 0.801 , 0.8086, 0.814 ,
#        0.8193, 0.8228, 0.8247], dtype=float16), 'query_nway_recall': array([0.2013, 0.855 , 0.903 , 0.9097, 0.9116, 0.914 , 0.9155, 0.915 ,
#        0.9165, 0.9175, 0.9175], dtype=float16), 'distractor_query_nway_recall': array([1.    , 0.9614, 0.885 , 0.8765, 0.8726, 0.8687, 0.871 , 0.8726,
#        0.87  , 0.8687, 0.8677], dtype=float16)}
# step: 11130 	training acc: {'total_query_nway': array([0.54727273, 0.76      , 0.85272727, 0.88      , 0.89454545,
#        0.89636364]), 'label_query_nway_recall': array([0.004, 0.488, 0.728, 0.788, 0.824, 0.836]), 'query_nway_recall': array([0.196, 0.82 , 0.908, 0.932, 0.932, 0.928]), 'distractor_query_nway_recall': array([1.        , 0.98666667, 0.95666667, 0.95666667, 0.95333333,
#        0.94666667])}
# step: 11160 	training acc: {'total_query_nway': array([0.54545455, 0.67454545, 0.76727273, 0.78727273, 0.78909091,
#        0.79818182]), 'label_query_nway_recall': array([0.   , 0.288, 0.54 , 0.592, 0.612, 0.652]), 'query_nway_recall': array([0.144, 0.688, 0.724, 0.748, 0.764, 0.788]), 'distractor_query_nway_recall': array([1.        , 0.99666667, 0.95666667, 0.95      , 0.93666667,
#        0.92      ])}
# step: 11190 	training acc: {'total_query_nway': array([0.54545455, 0.71090909, 0.84545455, 0.86      , 0.86545455,
#        0.86363636]), 'label_query_nway_recall': array([0.   , 0.392, 0.724, 0.772, 0.788, 0.812]), 'query_nway_recall': array([0.204, 0.88 , 0.884, 0.892, 0.892, 0.896]), 'distractor_query_nway_recall': array([1.        , 0.97666667, 0.94666667, 0.93333333, 0.93      ,
#        0.90666667])}
# 11200
# Test acc: {'total_query_nway': array([0.    , 0.7173, 0.7905, 0.818 , 0.8306, 0.838 , 0.844 , 0.852 ,
#        0.856 , 0.858 , 0.8623], dtype=float16), 'query_nway_recall': array([0.2015, 0.898 , 0.9346, 0.9424, 0.9473, 0.9463, 0.9497, 0.951 ,
#        0.9507, 0.951 , 0.9517], dtype=float16), 'distractor_query_nway_recall': array([1.    , 0.975 , 0.919 , 0.9087, 0.9023, 0.9014, 0.9   , 0.9   ,
#        0.899 , 0.899 , 0.9   ], dtype=float16)}
# step: 11220 	training acc: {'total_query_nway': array([0.54545455, 0.68181818, 0.76      , 0.77818182, 0.78727273,
#        0.79272727]), 'label_query_nway_recall': array([0.004, 0.348, 0.604, 0.684, 0.7  , 0.72 ]), 'query_nway_recall': array([0.16 , 0.704, 0.788, 0.812, 0.812, 0.82 ]), 'distractor_query_nway_recall': array([0.99666667, 0.96      , 0.89      , 0.85666667, 0.86      ,
#        0.85333333])}
# step: 11250 	training acc: {'total_query_nway': array([0.54545455, 0.63636364, 0.78727273, 0.81818182, 0.82727273,
#        0.83454545]), 'label_query_nway_recall': array([0.   , 0.216, 0.68 , 0.732, 0.752, 0.772]), 'query_nway_recall': array([0.252, 0.828, 0.88 , 0.896, 0.904, 0.908]), 'distractor_query_nway_recall': array([1.        , 0.98666667, 0.87666667, 0.89      , 0.89      ,
#        0.88666667])}
# step: 11280 	training acc: {'total_query_nway': array([0.54545455, 0.79818182, 0.97636364, 0.98727273, 0.98727273,
#        0.98909091]), 'label_query_nway_recall': array([0.   , 0.556, 0.948, 0.972, 0.972, 0.976]), 'query_nway_recall': array([0.2  , 0.984, 0.996, 0.996, 0.996, 0.996]), 'distractor_query_nway_recall': array([1., 1., 1., 1., 1., 1.])}
# 11300
# Test acc: {'total_query_nway': array([0.    , 0.7095, 0.763 , 0.788 , 0.802 , 0.811 , 0.8223, 0.826 ,
#        0.8315, 0.8354, 0.8394], dtype=float16), 'query_nway_recall': array([0.1992, 0.894 , 0.9336, 0.938 , 0.943 , 0.942 , 0.946 , 0.9463,
#        0.948 , 0.9487, 0.9487], dtype=float16), 'distractor_query_nway_recall': array([1.    , 0.971 , 0.919 , 0.916 , 0.915 , 0.911 , 0.9077, 0.9077,
#        0.9087, 0.9077, 0.9062], dtype=float16)}
# step: 11310 	training acc: {'total_query_nway': array([0.54545455, 0.70181818, 0.84181818, 0.86181818, 0.86727273,
#        0.86909091]), 'label_query_nway_recall': array([0.   , 0.344, 0.672, 0.716, 0.732, 0.752]), 'query_nway_recall': array([0.248, 0.824, 0.86 , 0.876, 0.876, 0.876]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.98333333, 0.98333333, 0.98      ,
#        0.96666667])}
# step: 11340 	training acc: {'total_query_nway': array([0.54727273, 0.7       , 0.83090909, 0.84545455, 0.85272727,
#        0.85818182]), 'label_query_nway_recall': array([0.004, 0.364, 0.716, 0.736, 0.748, 0.76 ]), 'query_nway_recall': array([0.232, 0.844, 0.86 , 0.872, 0.872, 0.872]), 'distractor_query_nway_recall': array([1.        , 0.98      , 0.92666667, 0.93666667, 0.94      ,
#        0.94      ])}
# step: 11370 	training acc: {'total_query_nway': array([0.54545455, 0.76      , 0.87272727, 0.87636364, 0.87636364,
#        0.88909091]), 'label_query_nway_recall': array([0.   , 0.488, 0.764, 0.8  , 0.82 , 0.848]), 'query_nway_recall': array([0.084, 0.876, 0.876, 0.88 , 0.884, 0.892]), 'distractor_query_nway_recall': array([1.        , 0.98666667, 0.96333333, 0.94      , 0.92333333,
#        0.92333333])}
# step: 11400 	training acc: {'total_query_nway': array([0.54545455, 0.75272727, 0.91454545, 0.93272727, 0.93454545,
#        0.94727273]), 'label_query_nway_recall': array([0.   , 0.464, 0.864, 0.904, 0.908, 0.936]), 'query_nway_recall': array([0.26 , 0.908, 0.98 , 0.988, 0.988, 0.988]), 'distractor_query_nway_recall': array([1.        , 0.99333333, 0.95666667, 0.95666667, 0.95666667,
#        0.95666667])}
# 11400
# Test acc: {'total_query_nway': array([0.    , 0.691 , 0.772 , 0.8013, 0.8184, 0.825 , 0.8354, 0.8394,
#        0.842 , 0.845 , 0.8467], dtype=float16), 'query_nway_recall': array([0.2123, 0.8965, 0.928 , 0.933 , 0.939 , 0.9404, 0.945 , 0.9463,
#        0.9463, 0.9463, 0.947 ], dtype=float16), 'distractor_query_nway_recall': array([1.    , 0.964 , 0.915 , 0.9136, 0.9087, 0.9   , 0.8965, 0.8965,
#        0.89  , 0.885 , 0.8823], dtype=float16)}
# step: 11430 	training acc: {'total_query_nway': array([0.54545455, 0.84      , 0.95090909, 0.96363636, 0.97090909,
#        0.97636364]), 'label_query_nway_recall': array([0.   , 0.656, 0.904, 0.932, 0.944, 0.956]), 'query_nway_recall': array([0.188, 0.948, 0.976, 0.98 , 0.98 , 0.98 ]), 'distractor_query_nway_recall': array([1.        , 0.99333333, 0.99      , 0.99      , 0.99333333,
#        0.99333333])}
# step: 11460 	training acc: {'total_query_nway': array([0.54545455, 0.77818182, 0.88727273, 0.89636364, 0.9       ,
#        0.90727273]), 'label_query_nway_recall': array([0.   , 0.556, 0.88 , 0.908, 0.912, 0.916]), 'query_nway_recall': array([0.216, 0.968, 0.996, 0.996, 0.996, 0.996]), 'distractor_query_nway_recall': array([1.        , 0.96333333, 0.89333333, 0.88666667, 0.89      ,
#        0.9       ])}
# step: 11490 	training acc: {'total_query_nway': array([0.54545455, 0.69454545, 0.91272727, 0.94181818, 0.94909091,
#        0.96      ]), 'label_query_nway_recall': array([0.   , 0.328, 0.816, 0.876, 0.896, 0.92 ]), 'query_nway_recall': array([0.084, 0.972, 0.98 , 0.984, 0.984, 0.988]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99333333, 0.99666667, 0.99333333,
#        0.99333333])}
# 11500
# Test acc: {'total_query_nway': array([0.    , 0.6646, 0.711 , 0.7456, 0.7617, 0.7715, 0.7783, 0.7817,
#        0.7866, 0.7896, 0.7925], dtype=float16), 'query_nway_recall': array([0.1708, 0.868 , 0.9126, 0.92  , 0.9243, 0.9253, 0.9287, 0.9277,
#        0.928 , 0.929 , 0.929 ], dtype=float16), 'distractor_query_nway_recall': array([1.    , 0.98  , 0.9175, 0.915 , 0.915 , 0.9136, 0.9136, 0.91  ,
#        0.9077, 0.9062, 0.904 ], dtype=float16)}
# step: 11520 	training acc: {'total_query_nway': array([0.54545455, 0.65818182, 0.74909091, 0.76909091, 0.78545455,
#        0.78545455]), 'label_query_nway_recall': array([0.   , 0.248, 0.46 , 0.512, 0.576, 0.6  ]), 'query_nway_recall': array([0.228, 0.724, 0.768, 0.78 , 0.804, 0.8  ]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.99      , 0.98333333, 0.96      ,
#        0.94      ])}
# step: 11550 	training acc: {'total_query_nway': array([0.54545455, 0.70181818, 0.86363636, 0.90909091, 0.92      ,
#        0.93636364]), 'label_query_nway_recall': array([0.   , 0.348, 0.816, 0.896, 0.908, 0.936]), 'query_nway_recall': array([0.196, 0.948, 0.964, 0.98 , 0.98 , 0.98 ]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.90333333, 0.92      , 0.93      ,
#        0.93666667])}
# step: 11580 	training acc: {'total_query_nway': array([0.54545455, 0.74363636, 0.85454545, 0.85090909, 0.85272727,
#        0.85818182]), 'label_query_nway_recall': array([0.   , 0.436, 0.7  , 0.728, 0.752, 0.756]), 'query_nway_recall': array([0.212, 0.796, 0.836, 0.836, 0.836, 0.844]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.98333333, 0.95333333, 0.93666667,
#        0.94333333])}
# 11600
# Test acc: {'total_query_nway': array([0.    , 0.7485, 0.7783, 0.8066, 0.8237, 0.8306, 0.8364, 0.8403,
#        0.8467, 0.85  , 0.852 ], dtype=float16), 'query_nway_recall': array([0.2202, 0.905 , 0.9316, 0.939 , 0.941 , 0.943 , 0.944 , 0.944 ,
#        0.9434, 0.945 , 0.9453], dtype=float16), 'distractor_query_nway_recall': array([1.    , 0.9624, 0.919 , 0.919 , 0.915 , 0.9062, 0.904 , 0.9   ,
#        0.8975, 0.8975, 0.895 ], dtype=float16)}
# step: 11610 	training acc: {'total_query_nway': array([0.54545455, 0.70545455, 0.84545455, 0.85454545, 0.85272727,
#        0.85636364]), 'label_query_nway_recall': array([0.   , 0.408, 0.764, 0.776, 0.78 , 0.788]), 'query_nway_recall': array([0.168, 0.844, 0.884, 0.896, 0.888, 0.884]), 'distractor_query_nway_recall': array([1.        , 0.95333333, 0.91333333, 0.92      , 0.91333333,
#        0.91333333])}
# step: 11640 	training acc: {'total_query_nway': array([0.54545455, 0.76181818, 0.90909091, 0.92727273, 0.93454545,
#        0.93272727]), 'label_query_nway_recall': array([0.   , 0.516, 0.848, 0.896, 0.916, 0.916]), 'query_nway_recall': array([0.304, 0.944, 0.956, 0.964, 0.964, 0.968]), 'distractor_query_nway_recall': array([1.        , 0.96666667, 0.96      , 0.95333333, 0.95      ,
#        0.94666667])}
# step: 11670 	training acc: {'total_query_nway': array([0.54545455, 0.84909091, 0.92545455, 0.92727273, 0.94      ,
#        0.94181818]), 'label_query_nway_recall': array([0.   , 0.672, 0.84 , 0.844, 0.872, 0.876]), 'query_nway_recall': array([0.244, 0.928, 0.928, 0.936, 0.94 , 0.952]), 'distractor_query_nway_recall': array([1.        , 0.99666667, 0.99666667, 0.99666667, 0.99666667,
#        0.99666667])}
# step: 11700 	training acc: {'total_query_nway': array([0.54545455, 0.74181818, 0.86363636, 0.86909091, 0.87454545,
#        0.87818182]), 'label_query_nway_recall': array([0.   , 0.448, 0.72 , 0.732, 0.752, 0.76 ]), 'query_nway_recall': array([0.208, 0.736, 0.848, 0.868, 0.872, 0.872]), 'distractor_query_nway_recall': array([1.        , 0.98666667, 0.98333333, 0.98333333, 0.97666667,
#        0.97666667])}
# 11700
# Test acc: {'total_query_nway': array([0.    , 0.724 , 0.8066, 0.83  , 0.8467, 0.851 , 0.858 , 0.8633,
#        0.866 , 0.868 , 0.8706], dtype=float16), 'query_nway_recall': array([0.1932, 0.9023, 0.937 , 0.9453, 0.952 , 0.953 , 0.9556, 0.957 ,
#        0.957 , 0.957 , 0.958 ], dtype=float16), 'distractor_query_nway_recall': array([1.    , 0.9663, 0.8975, 0.884 , 0.8823, 0.8765, 0.8726, 0.871 ,
#        0.871 , 0.871 , 0.87  ], dtype=float16)}
# step: 11730 	training acc: {'total_query_nway': array([0.54545455, 0.70545455, 0.77636364, 0.79272727, 0.80363636,
#        0.82      ]), 'label_query_nway_recall': array([0.   , 0.352, 0.536, 0.592, 0.64 , 0.688]), 'query_nway_recall': array([0.204, 0.756, 0.804, 0.824, 0.828, 0.828]), 'distractor_query_nway_recall': array([1.        , 1.        , 0.97666667, 0.96      , 0.94      ,
#        0.93      ])}
# step: 11760 	training acc: {'total_query_nway': array([0.54727273, 0.77090909, 0.87090909, 0.90727273, 0.91454545,
#        0.92727273]), 'label_query_nway_recall': array([0.004, 0.5  , 0.76 , 0.812, 0.828, 0.852]), 'query_nway_recall': array([0.168, 0.832, 0.868, 0.884, 0.896, 0.908]), 'distractor_query_nway_recall': array([1.        , 0.99666667, 0.96333333, 0.98666667, 0.98666667,
#        0.99      ])}
# step: 11790 	training acc: {'total_query_nway': array([0.54545455, 0.71636364, 0.85272727, 0.87090909, 0.88545455,
#        0.89090909]), 'label_query_nway_recall': array([0.   , 0.412, 0.744, 0.796, 0.832, 0.852]), 'query_nway_recall': array([0.232, 0.856, 0.908, 0.928, 0.928, 0.94 ]), 'distractor_query_nway_recall': array([1.        , 0.97      , 0.94333333, 0.93333333, 0.93      ,
#        0.92333333])}
# 11800
# Test acc: {'total_query_nway': array([0.    , 0.6777, 0.757 , 0.7935, 0.8066, 0.8164, 0.8237, 0.829 ,
#        0.8354, 0.8384, 0.842 ], dtype=float16), 'query_nway_recall': array([0.2015, 0.9043, 0.935 , 0.943 , 0.9453, 0.9453, 0.947 , 0.948 ,
#        0.9497, 0.9497, 0.9497], dtype=float16), 'distractor_query_nway_recall': array([1.    , 0.976 , 0.936 , 0.935 , 0.9277, 0.9224, 0.9175, 0.9136,
#        0.9136, 0.9126, 0.911 ], dtype=float16)}
# step: 11820 	training acc: {'total_query_nway': array([0.54545455, 0.70545455, 0.83272727, 0.86181818, 0.87636364,
#        0.87818182]), 'label_query_nway_recall': array([0.   , 0.356, 0.656, 0.724, 0.76 , 0.776]), 'query_nway_recall': array([0.204, 0.82 , 0.844, 0.872, 0.872, 0.876]), 'distractor_query_nway_recall': array([1.        , 0.99666667, 0.98      , 0.97666667, 0.97333333,
#        0.96333333])}
# step: 11850 	training acc: {'total_query_nway': array([0.54545455, 0.72      , 0.91818182, 0.93090909, 0.94545455,
#        0.95636364]), 'label_query_nway_recall': array([0.   , 0.388, 0.856, 0.892, 0.912, 0.94 ]), 'query_nway_recall': array([0.164, 0.952, 0.968, 0.984, 0.984, 0.984]), 'distractor_query_nway_recall': array([1.        , 0.99666667, 0.97      , 0.96333333, 0.97333333,
#        0.97      ])}
# step: 11880 	training acc: {'total_query_nway': array([0.54363636, 0.69272727, 0.84181818, 0.85090909, 0.86363636,
#        0.85454545]), 'label_query_nway_recall': array([0.   , 0.352, 0.668, 0.712, 0.744, 0.756]), 'query_nway_recall': array([0.172, 0.816, 0.852, 0.876, 0.884, 0.896]), 'distractor_query_nway_recall': array([0.99666667, 0.97666667, 0.98666667, 0.96666667, 0.96333333,
#        0.93666667])}
# 11900
# Test acc: {'total_query_nway': array([0.    , 0.7188, 0.7627, 0.8   , 0.811 , 0.8237, 0.831 , 0.8384,
#        0.843 , 0.8467, 0.85  ], dtype=float16), 'query_nway_recall': array([0.1992, 0.915 , 0.9385, 0.9453, 0.947 , 0.9517, 0.9536, 0.954 ,
#        0.9546, 0.954 , 0.955 ], dtype=float16), 'distractor_query_nway_recall': array([1.    , 0.9785, 0.93  , 0.936 , 0.9375, 0.9375, 0.9336, 0.9336,
#        0.9336, 0.9336, 0.9326], dtype=float16)}
# step: 11910 	training acc: {'total_query_nway': array([0.54545455, 0.87090909, 0.90909091, 0.92909091, 0.93454545,
#        0.94545455]), 'label_query_nway_recall': array([0.   , 0.732, 0.932, 0.952, 0.956, 0.96 ]), 'query_nway_recall': array([0.14 , 0.952, 0.984, 0.992, 0.992, 0.992]), 'distractor_query_nway_recall': array([1.        , 0.98666667, 0.89      , 0.91      , 0.91666667,
#        0.93333333])}
# step: 11940 	training acc: {'total_query_nway': array([0.54545455, 0.69090909, 0.79090909, 0.80181818, 0.80909091,
#        0.80909091]), 'label_query_nway_recall': array([0.   , 0.328, 0.576, 0.592, 0.608, 0.62 ]), 'query_nway_recall': array([0.172, 0.744, 0.76 , 0.768, 0.768, 0.776]), 'distractor_query_nway_recall': array([1.        , 0.99666667, 0.97      , 0.97666667, 0.97666667,
#        0.96666667])}
# step: 11970 	training acc: {'total_query_nway': array([0.54545455, 0.74181818, 0.84909091, 0.85818182, 0.87272727,
#        0.87454545]), 'label_query_nway_recall': array([0.   , 0.44 , 0.74 , 0.752, 0.792, 0.804]), 'query_nway_recall': array([0.104, 0.812, 0.844, 0.844, 0.844, 0.848]), 'distractor_query_nway_recall': array([1.        , 0.99333333, 0.94      , 0.94666667, 0.94      ,
#        0.93666667])}

# %%
step
# Out:
# 12000
